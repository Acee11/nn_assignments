# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here

            # ideas from http://stats.stackexchange.com/questions/47590/what-are-good-initial-weights-in-a-neural-network
            
            # if activation is hyperbolic tangent
            weight_init = Uniform(width = np.sqrt(6/(num_in + num_out)))
            #if activation is sigmoid
            #weight_init = Uniform(width = 4*np.sqrt(6/(num_in + num_out)))
            
            
            
            #weight_init = Uniform(width = 1/(np.sqrt(num_in)))
            
            #weight_init = IsotropicGaussian(std = 0.01)
            #weight_init = Constant(1.0)
            
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        #
        # TODO: fill in gradient computation
        #
        dLdX = self.W.T.dot(dLdY)
        
        return dLdX
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        return dLdY * (np.ones_like(Y) - Y**2)
    
class SigmoidLayer(Layer):
    def __init__(self, **kwargs):
        super(SigmoidLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = sigmoid(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        return dLdY * (Y * (np.ones_like(Y) - Y))

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            #print(X.shape)
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in range(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            #print(fp_context)
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            #print("dLdP shape: ", dLdP)
            dLdX = layer.bprop(dLdX, fp_context)
            
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in range(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print("Iter: %d, loss increased!!" % (i,))
        if (old_L - L)<tolerance:
            print("Tolerance level reached exiting")
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print("At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100))
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])


GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-37f4a3e827d3> in <module>()
#      19         SoftMaxLayer()
#      20         ])
# ---> 21 GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
#
# <ipython-input-36-0e20cb32aa10> in GD(net, X, Y, alpha, max_iters, tolerance)
#       6     old_L = np.inf
#       7     for i in range(max_iters):
# ----> 8         L, O, gradients = net.get_cost_and_gradient(X, Y)
#       9         if old_L < L:
#      10             print("Iter: %d, loss increased!!" % (i,))
#
# <ipython-input-35-409ec0b3d6f8> in get_cost_and_gradient(self, X, Y)
#     185         for layer in self.layers[:-1]:
#     186             #print(X.shape)
# --> 187             X, fp_context = layer.fprop(X)
#     188             fp_contexts.append(fp_context)
#     189
#
# <ipython-input-35-409ec0b3d6f8> in fprop(self, X)
#      57         #Save X for later reusal
#      58         fprop_context = dict(X=X)
# ---> 59         Y = np.dot(self.W, X) +  self.b
#      60
#      61         return Y, fprop_context
#
# ValueError: shapes (100,784) and (4,150) not aligned: 784 (dim 1) != 4 (dim 0)

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print("The streams return batches containing %s" % (mnist_train_stream.sources,))

print("Each trainin batch consits of a tuple containing:")
for element in next(mnist_train_stream.get_epoch_iterator()):
    print(" - an array of size %s containing %s" % (element.shape, element.dtype))
    
print("Validation/test batches consits of tuples containing:")
for element in next(mnist_test_stream.get_epoch_iterator()):
    print(" - an array of size %s containing %s" % (element.shape, element.dtype))
# Out:
# The streams return batches containing ('features', 'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def SGD(net, train_stream, validation_stream, test_stream, alp=(5e-1, 5e-3), alp_dropout=20000, delta = 1e-1, lambd = 7e-3, epsilon = 5e-3):
    i=0
    e=0
    
    #initialize momentum variables
    #
    # TODO
    #
    # Hint: you need one valocity matrix for each parameter
    velocities = [0. for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    train_erros = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = 3
    patience_expansion = 1.5
    
    val_error_rate = np.inf
    prev_val_error_rate = np.inf
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_erros.append((i,err_rate))
                if i % 100 == 0:
                    print("At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100))
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N == 'W':
                        pass
                        #
                        # TODO: implement the weight decay addition to gradient
                        #
                        G += lambd*P
                    
                    #
                    # TODO: set a learning rate
                    #
                    # Hint, use the iteration counter i
                    alpha = alp[1] - (alp[1] - alp[0]) * (alp_dropout / (alp_dropout + i))
                    
                    
                    #
                    # TODO: set the momentum constant 
                    # 
                    
                   
                    
                    #
                    # TODO: implement velocity update in momentum
                    #
                    old_V = V
                    V = epsilon * (G + old_V)
                    
                    #
                    # TODO: set a more sensible learning rule here,
                    # using your learning rate schedule and momentum
                    #
                    #!!!!! Need to modify the actual parameter here! 
                    P += -alpha * G + old_V
            # After an epoch compute validation error
            prev_val_error_rate = val_error_rate
            val_error_rate = compute_error_rate(net, validation_stream)
            
            if prev_val_error_rate >= val_error_rate:
                alpha *= 1.05
            elif (abs(prev_val_error_rate - val_error_rate) >= delta):
                alpha /= 1.5
            
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            print("After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
                e, val_error_rate, number_of_epochs))
            
    except KeyboardInterrupt:
        print("Setting network parameters from after epoch %d" %(best_params_epoch))
        net.parameters = best_params
        
        subplot(2,1,1)
        train_loss = np.array(train_loss)
        semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
        legend()
        
        subplot(2,1,2)
        train_erros = np.array(train_erros)
        plot(train_erros[:,0], train_erros[:,1], label='batch train error rate')
        validation_errors = np.array(validation_errors)
        plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
        ylim(0,0.2)
        legend()

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
# TODO: pick a network architecture here. The one below is just 
# softmax regression

net = FeedForwardNet([
        AffineLayer(784,90),
        ReLULayer(),
        AffineLayer(90,30),
        TanhLayer(),
        AffineLayer(30,10),
        SoftMaxLayer()
        ])


SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
   alp=(4e-2, 7e-3),
   alp_dropout=30000.,
   delta = 1e-1,
   lambd = 1e-3,
   epsilon = 1e-10)

print("Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), ))
# Out:
# At minibatch 100, batch loss 1.014782, batch error rate 16.000000%
# At minibatch 200, batch loss 0.621948, batch error rate 15.000000%
# At minibatch 300, batch loss 0.466646, batch error rate 13.000000%
# At minibatch 400, batch loss 0.501019, batch error rate 13.000000%
# At minibatch 500, batch loss 0.468683, batch error rate 13.000000%
# After epoch 1: valid_err_rate: 0.096500% currently going to do 3 epochs
# At minibatch 600, batch loss 0.373487, batch error rate 9.000000%
# At minibatch 700, batch loss 0.359993, batch error rate 9.000000%
# At minibatch 800, batch loss 0.359288, batch error rate 12.000000%
# At minibatch 900, batch loss 0.307560, batch error rate 8.000000%
# At minibatch 1000, batch loss 0.375435, batch error rate 11.000000%
# After epoch 2: valid_err_rate: 0.075000% currently going to do 4 epochs
# At minibatch 1100, batch loss 0.279427, batch error rate 10.000000%
# At minibatch 1200, batch loss 0.182695, batch error rate 3.000000%
# At minibatch 1300, batch loss 0.242616, batch error rate 7.000000%
# At minibatch 1400, batch loss 0.109370, batch error rate 3.000000%
# At minibatch 1500, batch loss 0.176602, batch error rate 5.000000%
# After epoch 3: valid_err_rate: 0.063400% currently going to do 5 epochs
# At minibatch 1600, batch loss 0.313270, batch error rate 7.000000%
# At minibatch 1700, batch loss 0.202385, batch error rate 6.000000%
# At minibatch 1800, batch loss 0.334731, batch error rate 8.000000%
# At minibatch 1900, batch loss 0.281068, batch error rate 7.000000%
# At minibatch 2000, batch loss 0.323201, batch error rate 9.000000%
# After epoch 4: valid_err_rate: 0.053200% currently going to do 7 epochs
# At minibatch 2100, batch loss 0.345932, batch error rate 10.000000%
# At minibatch 2200, batch loss 0.190770, batch error rate 9.000000%
# At minibatch 2300, batch loss 0.171022, batch error rate 6.000000%
# At minibatch 2400, batch loss 0.186860, batch error rate 6.000000%
# At minibatch 2500, batch loss 0.130760, batch error rate 4.000000%
# After epoch 5: valid_err_rate: 0.046800% currently going to do 8 epochs
# At minibatch 2600, batch loss 0.132967, batch error rate 4.000000%
# At minibatch 2700, batch loss 0.082970, batch error rate 2.000000%
# At minibatch 2800, batch loss 0.205210, batch error rate 7.000000%
# At minibatch 2900, batch loss 0.288599, batch error rate 10.000000%
# At minibatch 3000, batch loss 0.096534, batch error rate 2.000000%
# After epoch 6: valid_err_rate: 0.044400% currently going to do 10 epochs
# At minibatch 3100, batch loss 0.354983, batch error rate 9.000000%
# At minibatch 3200, batch loss 0.238116, batch error rate 9.000000%
# At minibatch 3300, batch loss 0.134119, batch error rate 2.000000%
# At minibatch 3400, batch loss 0.211102, batch error rate 8.000000%
# At minibatch 3500, batch loss 0.198401, batch error rate 5.000000%
# After epoch 7: valid_err_rate: 0.038800% currently going to do 11 epochs
# At minibatch 3600, batch loss 0.312837, batch error rate 8.000000%
# At minibatch 3700, batch loss 0.154842, batch error rate 5.000000%
# At minibatch 3800, batch loss 0.099546, batch error rate 3.000000%
# At minibatch 3900, batch loss 0.090939, batch error rate 1.000000%
# At minibatch 4000, batch loss 0.210948, batch error rate 5.000000%
# After epoch 8: valid_err_rate: 0.039000% currently going to do 11 epochs
# At minibatch 4100, batch loss 0.179331, batch error rate 4.000000%
# At minibatch 4200, batch loss 0.137739, batch error rate 5.000000%
# At minibatch 4300, batch loss 0.101200, batch error rate 4.000000%
# At minibatch 4400, batch loss 0.089113, batch error rate 1.000000%
# At minibatch 4500, batch loss 0.084448, batch error rate 4.000000%
# After epoch 9: valid_err_rate: 0.034000% currently going to do 14 epochs
# At minibatch 4600, batch loss 0.065937, batch error rate 2.000000%
# At minibatch 4700, batch loss 0.083019, batch error rate 3.000000%
# At minibatch 4800, batch loss 0.069478, batch error rate 1.000000%
# At minibatch 4900, batch loss 0.075121, batch error rate 1.000000%
# At minibatch 5000, batch loss 0.134843, batch error rate 3.000000%
# After epoch 10: valid_err_rate: 0.033200% currently going to do 16 epochs
# At minibatch 5100, batch loss 0.046386, batch error rate 1.000000%
# At minibatch 5200, batch loss 0.193543, batch error rate 4.000000%
# At minibatch 5300, batch loss 0.198328, batch error rate 6.000000%
# At minibatch 5400, batch loss 0.129858, batch error rate 5.000000%
# At minibatch 5500, batch loss 0.163741, batch error rate 6.000000%
# After epoch 11: valid_err_rate: 0.032100% currently going to do 17 epochs
# At minibatch 5600, batch loss 0.141299, batch error rate 3.000000%
# At minibatch 5700, batch loss 0.087518, batch error rate 2.000000%
# At minibatch 5800, batch loss 0.099363, batch error rate 3.000000%
# At minibatch 5900, batch loss 0.091205, batch error rate 3.000000%
# At minibatch 6000, batch loss 0.085592, batch error rate 3.000000%
# After epoch 12: valid_err_rate: 0.032200% currently going to do 17 epochs
# At minibatch 6100, batch loss 0.043446, batch error rate 1.000000%
# At minibatch 6200, batch loss 0.077403, batch error rate 1.000000%
# At minibatch 6300, batch loss 0.152562, batch error rate 5.000000%
# At minibatch 6400, batch loss 0.088452, batch error rate 2.000000%
# At minibatch 6500, batch loss 0.090406, batch error rate 3.000000%
# After epoch 13: valid_err_rate: 0.033200% currently going to do 17 epochs
# At minibatch 6600, batch loss 0.077107, batch error rate 2.000000%
# At minibatch 6700, batch loss 0.101169, batch error rate 4.000000%
# At minibatch 6800, batch loss 0.098229, batch error rate 3.000000%
# At minibatch 6900, batch loss 0.063622, batch error rate 1.000000%
# At minibatch 7000, batch loss 0.052209, batch error rate 0.000000%
# After epoch 14: valid_err_rate: 0.031000% currently going to do 22 epochs
# At minibatch 7100, batch loss 0.121850, batch error rate 4.000000%
# At minibatch 7200, batch loss 0.073958, batch error rate 3.000000%
# At minibatch 7300, batch loss 0.055648, batch error rate 2.000000%
# At minibatch 7400, batch loss 0.110860, batch error rate 5.000000%
# At minibatch 7500, batch loss 0.019592, batch error rate 0.000000%
# After epoch 15: valid_err_rate: 0.027900% currently going to do 23 epochs
# At minibatch 7600, batch loss 0.074129, batch error rate 2.000000%
# At minibatch 7700, batch loss 0.098712, batch error rate 4.000000%
# At minibatch 7800, batch loss 0.034048, batch error rate 0.000000%
# At minibatch 7900, batch loss 0.098841, batch error rate 4.000000%
# At minibatch 8000, batch loss 0.066425, batch error rate 2.000000%
# After epoch 16: valid_err_rate: 0.028900% currently going to do 23 epochs
# At minibatch 8100, batch loss 0.033337, batch error rate 0.000000%
# At minibatch 8200, batch loss 0.077340, batch error rate 3.000000%
# At minibatch 8300, batch loss 0.107654, batch error rate 3.000000%
# At minibatch 8400, batch loss 0.134882, batch error rate 5.000000%
# At minibatch 8500, batch loss 0.083757, batch error rate 3.000000%
# After epoch 17: valid_err_rate: 0.027700% currently going to do 26 epochs
# At minibatch 8600, batch loss 0.057682, batch error rate 1.000000%
# At minibatch 8700, batch loss 0.046383, batch error rate 1.000000%
# At minibatch 8800, batch loss 0.061052, batch error rate 0.000000%
# At minibatch 8900, batch loss 0.069489, batch error rate 3.000000%
# At minibatch 9000, batch loss 0.070037, batch error rate 3.000000%
# After epoch 18: valid_err_rate: 0.027700% currently going to do 26 epochs
# At minibatch 9100, batch loss 0.080975, batch error rate 1.000000%
# At minibatch 9200, batch loss 0.070746, batch error rate 1.000000%
# At minibatch 9300, batch loss 0.046399, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.054090, batch error rate 1.000000%
# At minibatch 9500, batch loss 0.103566, batch error rate 3.000000%
# After epoch 19: valid_err_rate: 0.028300% currently going to do 26 epochs
# At minibatch 9600, batch loss 0.054845, batch error rate 1.000000%
# At minibatch 9700, batch loss 0.084269, batch error rate 4.000000%
# At minibatch 9800, batch loss 0.140246, batch error rate 3.000000%
# At minibatch 9900, batch loss 0.050561, batch error rate 1.000000%
# At minibatch 10000, batch loss 0.073303, batch error rate 1.000000%
# After epoch 20: valid_err_rate: 0.027200% currently going to do 31 epochs
# At minibatch 10100, batch loss 0.054204, batch error rate 3.000000%
# At minibatch 10200, batch loss 0.064885, batch error rate 2.000000%
# At minibatch 10300, batch loss 0.029281, batch error rate 0.000000%
# At minibatch 10400, batch loss 0.192326, batch error rate 5.000000%
# At minibatch 10500, batch loss 0.121132, batch error rate 2.000000%
# After epoch 21: valid_err_rate: 0.026000% currently going to do 32 epochs
# At minibatch 10600, batch loss 0.063447, batch error rate 1.000000%
# At minibatch 10700, batch loss 0.039877, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.026033, batch error rate 0.000000%
# At minibatch 10900, batch loss 0.058093, batch error rate 2.000000%
# At minibatch 11000, batch loss 0.048447, batch error rate 1.000000%
# After epoch 22: valid_err_rate: 0.025400% currently going to do 34 epochs
# At minibatch 11100, batch loss 0.074598, batch error rate 3.000000%
# At minibatch 11200, batch loss 0.079437, batch error rate 1.000000%
# At minibatch 11300, batch loss 0.025346, batch error rate 0.000000%
# At minibatch 11400, batch loss 0.100301, batch error rate 3.000000%
# At minibatch 11500, batch loss 0.045520, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 0.027000% currently going to do 34 epochs
# At minibatch 11600, batch loss 0.132541, batch error rate 4.000000%
# At minibatch 11700, batch loss 0.017969, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.100211, batch error rate 4.000000%
# At minibatch 11900, batch loss 0.045201, batch error rate 1.000000%
# At minibatch 12000, batch loss 0.040271, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.024500% currently going to do 37 epochs
# At minibatch 12100, batch loss 0.049512, batch error rate 1.000000%
# At minibatch 12200, batch loss 0.036533, batch error rate 0.000000%
# At minibatch 12300, batch loss 0.103519, batch error rate 2.000000%
# At minibatch 12400, batch loss 0.070349, batch error rate 1.000000%
# At minibatch 12500, batch loss 0.038097, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.026100% currently going to do 37 epochs
# At minibatch 12600, batch loss 0.062685, batch error rate 1.000000%
# At minibatch 12700, batch loss 0.049481, batch error rate 0.000000%
# At minibatch 12800, batch loss 0.049232, batch error rate 2.000000%
# At minibatch 12900, batch loss 0.057392, batch error rate 2.000000%
# At minibatch 13000, batch loss 0.086599, batch error rate 2.000000%
# After epoch 26: valid_err_rate: 0.027600% currently going to do 37 epochs
# At minibatch 13100, batch loss 0.075687, batch error rate 2.000000%
# At minibatch 13200, batch loss 0.048159, batch error rate 2.000000%
# At minibatch 13300, batch loss 0.016324, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.019340, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.049061, batch error rate 2.000000%
# After epoch 27: valid_err_rate: 0.026500% currently going to do 37 epochs
# At minibatch 13600, batch loss 0.034977, batch error rate 1.000000%
# At minibatch 13700, batch loss 0.104896, batch error rate 4.000000%
# At minibatch 13800, batch loss 0.056122, batch error rate 2.000000%
# At minibatch 13900, batch loss 0.085311, batch error rate 3.000000%
# At minibatch 14000, batch loss 0.075525, batch error rate 2.000000%
# After epoch 28: valid_err_rate: 0.024700% currently going to do 37 epochs
# At minibatch 14100, batch loss 0.063883, batch error rate 2.000000%
# At minibatch 14200, batch loss 0.068641, batch error rate 2.000000%
# At minibatch 14300, batch loss 0.031145, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.072941, batch error rate 1.000000%
# At minibatch 14500, batch loss 0.089799, batch error rate 4.000000%
# After epoch 29: valid_err_rate: 0.024300% currently going to do 44 epochs
# At minibatch 14600, batch loss 0.049382, batch error rate 2.000000%
# At minibatch 14700, batch loss 0.065403, batch error rate 2.000000%
# At minibatch 14800, batch loss 0.059722, batch error rate 2.000000%
# At minibatch 14900, batch loss 0.046585, batch error rate 1.000000%
# At minibatch 15000, batch loss 0.096756, batch error rate 3.000000%
# After epoch 30: valid_err_rate: 0.024000% currently going to do 46 epochs
# At minibatch 15100, batch loss 0.027400, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.036866, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.072856, batch error rate 2.000000%
# At minibatch 15400, batch loss 0.022390, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.050768, batch error rate 1.000000%
# After epoch 31: valid_err_rate: 0.024300% currently going to do 46 epochs
# At minibatch 15600, batch loss 0.026580, batch error rate 0.000000%
# At minibatch 15700, batch loss 0.051102, batch error rate 1.000000%
# At minibatch 15800, batch loss 0.019186, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.052008, batch error rate 1.000000%
# At minibatch 16000, batch loss 0.099784, batch error rate 3.000000%
# After epoch 32: valid_err_rate: 0.025200% currently going to do 46 epochs
# At minibatch 16100, batch loss 0.029238, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.025656, batch error rate 0.000000%
# At minibatch 16300, batch loss 0.034123, batch error rate 1.000000%
# At minibatch 16400, batch loss 0.033611, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.031650, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.023100% currently going to do 50 epochs
# At minibatch 16600, batch loss 0.016520, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.038512, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.070327, batch error rate 2.000000%
# At minibatch 16900, batch loss 0.068968, batch error rate 1.000000%
# At minibatch 17000, batch loss 0.059902, batch error rate 2.000000%
# After epoch 34: valid_err_rate: 0.024600% currently going to do 50 epochs
# At minibatch 17100, batch loss 0.033055, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.024045, batch error rate 1.000000%
# At minibatch 17300, batch loss 0.017753, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.054539, batch error rate 2.000000%
# At minibatch 17500, batch loss 0.058923, batch error rate 3.000000%
# After epoch 35: valid_err_rate: 0.024700% currently going to do 50 epochs
# At minibatch 17600, batch loss 0.034341, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.110474, batch error rate 2.000000%
# At minibatch 17800, batch loss 0.037753, batch error rate 2.000000%
# At minibatch 17900, batch loss 0.073397, batch error rate 2.000000%
# At minibatch 18000, batch loss 0.113299, batch error rate 3.000000%
# After epoch 36: valid_err_rate: 0.025100% currently going to do 50 epochs
# At minibatch 18100, batch loss 0.061133, batch error rate 3.000000%
# At minibatch 18200, batch loss 0.033426, batch error rate 2.000000%
# At minibatch 18300, batch loss 0.013802, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.060431, batch error rate 1.000000%
# At minibatch 18500, batch loss 0.059209, batch error rate 2.000000%
# After epoch 37: valid_err_rate: 0.025000% currently going to do 50 epochs
# At minibatch 18600, batch loss 0.055685, batch error rate 2.000000%
# At minibatch 18700, batch loss 0.029494, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.054709, batch error rate 1.000000%
# At minibatch 18900, batch loss 0.029063, batch error rate 1.000000%
# At minibatch 19000, batch loss 0.088502, batch error rate 1.000000%
# After epoch 38: valid_err_rate: 0.023200% currently going to do 50 epochs
# At minibatch 19100, batch loss 0.027061, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.048218, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.054696, batch error rate 1.000000%
# At minibatch 19400, batch loss 0.030906, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.049705, batch error rate 1.000000%
# After epoch 39: valid_err_rate: 0.026300% currently going to do 50 epochs
# At minibatch 19600, batch loss 0.090949, batch error rate 1.000000%
# At minibatch 19700, batch loss 0.056047, batch error rate 1.000000%
# At minibatch 19800, batch loss 0.050399, batch error rate 1.000000%
# At minibatch 19900, batch loss 0.051653, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.031833, batch error rate 1.000000%
# After epoch 40: valid_err_rate: 0.025000% currently going to do 50 epochs
# At minibatch 20100, batch loss 0.030991, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.032935, batch error rate 1.000000%
# At minibatch 20300, batch loss 0.039864, batch error rate 1.000000%
# At minibatch 20400, batch loss 0.039631, batch error rate 2.000000%
# At minibatch 20500, batch loss 0.057723, batch error rate 1.000000%
# After epoch 41: valid_err_rate: 0.025200% currently going to do 50 epochs
# At minibatch 20600, batch loss 0.025865, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.021089, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.027302, batch error rate 1.000000%
# At minibatch 20900, batch loss 0.060170, batch error rate 2.000000%
# At minibatch 21000, batch loss 0.028400, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.023300% currently going to do 50 epochs
# At minibatch 21100, batch loss 0.030386, batch error rate 1.000000%
# At minibatch 21200, batch loss 0.021986, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.036432, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.014813, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.079491, batch error rate 3.000000%
# After epoch 43: valid_err_rate: 0.022700% currently going to do 65 epochs
# At minibatch 21600, batch loss 0.020454, batch error rate 0.000000%
# At minibatch 21700, batch loss 0.057567, batch error rate 1.000000%
# At minibatch 21800, batch loss 0.016657, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.091206, batch error rate 1.000000%
# At minibatch 22000, batch loss 0.067709, batch error rate 1.000000%
# After epoch 44: valid_err_rate: 0.023200% currently going to do 65 epochs
# At minibatch 22100, batch loss 0.026477, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.046986, batch error rate 1.000000%
# At minibatch 22300, batch loss 0.070201, batch error rate 2.000000%
# At minibatch 22400, batch loss 0.030996, batch error rate 1.000000%
# At minibatch 22500, batch loss 0.027532, batch error rate 0.000000%
# After epoch 45: valid_err_rate: 0.023600% currently going to do 65 epochs
# At minibatch 22600, batch loss 0.026889, batch error rate 1.000000%
# At minibatch 22700, batch loss 0.037111, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.029056, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.022909, batch error rate 1.000000%
# At minibatch 23000, batch loss 0.040478, batch error rate 1.000000%
# After epoch 46: valid_err_rate: 0.023500% currently going to do 65 epochs
# At minibatch 23100, batch loss 0.105187, batch error rate 2.000000%
# At minibatch 23200, batch loss 0.044111, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.036075, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.023235, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.024050, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.025800% currently going to do 65 epochs
# At minibatch 23600, batch loss 0.036981, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.017926, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.020935, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.035013, batch error rate 1.000000%
# At minibatch 24000, batch loss 0.034039, batch error rate 1.000000%
# After epoch 48: valid_err_rate: 0.023400% currently going to do 65 epochs
# At minibatch 24100, batch loss 0.017652, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.033019, batch error rate 2.000000%
# At minibatch 24300, batch loss 0.028821, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.029648, batch error rate 1.000000%
# At minibatch 24500, batch loss 0.045158, batch error rate 1.000000%
# After epoch 49: valid_err_rate: 0.022400% currently going to do 74 epochs
# At minibatch 24600, batch loss 0.034991, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.060596, batch error rate 1.000000%
# At minibatch 24800, batch loss 0.014953, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.041581, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.050398, batch error rate 1.000000%
# After epoch 50: valid_err_rate: 0.023100% currently going to do 74 epochs
# At minibatch 25100, batch loss 0.022677, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.012699, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.058278, batch error rate 1.000000%
# At minibatch 25400, batch loss 0.070287, batch error rate 2.000000%
# At minibatch 25500, batch loss 0.026970, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.023000% currently going to do 74 epochs
# At minibatch 25600, batch loss 0.037308, batch error rate 1.000000%
# At minibatch 25700, batch loss 0.042728, batch error rate 1.000000%
# At minibatch 25800, batch loss 0.049360, batch error rate 2.000000%
# At minibatch 25900, batch loss 0.017634, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.023118, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.022900% currently going to do 74 epochs
# At minibatch 26100, batch loss 0.029068, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.038654, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.025482, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.014479, batch error rate 0.000000%
# At minibatch 26500, batch loss 0.045740, batch error rate 1.000000%
# After epoch 53: valid_err_rate: 0.021900% currently going to do 80 epochs
# At minibatch 26600, batch loss 0.034730, batch error rate 1.000000%
# At minibatch 26700, batch loss 0.019415, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.032635, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.020731, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.021303, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.021800% currently going to do 82 epochs
# At minibatch 27100, batch loss 0.040152, batch error rate 1.000000%
# At minibatch 27200, batch loss 0.029622, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.017559, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.020369, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.024757, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.022100% currently going to do 82 epochs
# At minibatch 27600, batch loss 0.033313, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.027601, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.035416, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.045829, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.036217, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.023900% currently going to do 82 epochs
# At minibatch 28100, batch loss 0.028894, batch error rate 1.000000%
# At minibatch 28200, batch loss 0.023952, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.070846, batch error rate 1.000000%
# At minibatch 28400, batch loss 0.034411, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.017802, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.021500% currently going to do 86 epochs
# At minibatch 28600, batch loss 0.044293, batch error rate 2.000000%
# At minibatch 28700, batch loss 0.035440, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.028341, batch error rate 0.000000%
# At minibatch 28900, batch loss 0.057861, batch error rate 2.000000%
# At minibatch 29000, batch loss 0.063651, batch error rate 2.000000%
# After epoch 58: valid_err_rate: 0.023700% currently going to do 86 epochs
# At minibatch 29100, batch loss 0.020715, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.029127, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.032413, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.045300, batch error rate 1.000000%
# At minibatch 29500, batch loss 0.020427, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.023400% currently going to do 86 epochs
# At minibatch 29600, batch loss 0.030580, batch error rate 1.000000%
# At minibatch 29700, batch loss 0.037106, batch error rate 1.000000%
# At minibatch 29800, batch loss 0.039443, batch error rate 1.000000%
# At minibatch 29900, batch loss 0.075550, batch error rate 2.000000%
# At minibatch 30000, batch loss 0.061511, batch error rate 1.000000%
# After epoch 60: valid_err_rate: 0.023500% currently going to do 86 epochs
# At minibatch 30100, batch loss 0.025109, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.047032, batch error rate 2.000000%
# At minibatch 30300, batch loss 0.030371, batch error rate 1.000000%
# At minibatch 30400, batch loss 0.025856, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.039015, batch error rate 1.000000%
# After epoch 61: valid_err_rate: 0.022900% currently going to do 86 epochs
# At minibatch 30600, batch loss 0.037718, batch error rate 1.000000%
# At minibatch 30700, batch loss 0.015107, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.036265, batch error rate 1.000000%
# At minibatch 30900, batch loss 0.015923, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.037392, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.022400% currently going to do 86 epochs
# At minibatch 31100, batch loss 0.024830, batch error rate 1.000000%
# At minibatch 31200, batch loss 0.017003, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.047876, batch error rate 1.000000%
# At minibatch 31400, batch loss 0.053680, batch error rate 1.000000%
# At minibatch 31500, batch loss 0.024726, batch error rate 0.000000%
# After epoch 63: valid_err_rate: 0.022300% currently going to do 86 epochs
# At minibatch 31600, batch loss 0.026671, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.040094, batch error rate 1.000000%
# At minibatch 31800, batch loss 0.029920, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.092596, batch error rate 3.000000%
# At minibatch 32000, batch loss 0.045085, batch error rate 1.000000%
# After epoch 64: valid_err_rate: 0.022200% currently going to do 86 epochs
# At minibatch 32100, batch loss 0.036682, batch error rate 1.000000%
# At minibatch 32200, batch loss 0.027232, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.038053, batch error rate 1.000000%
# At minibatch 32400, batch loss 0.044152, batch error rate 1.000000%
# At minibatch 32500, batch loss 0.069313, batch error rate 2.000000%
# After epoch 65: valid_err_rate: 0.022400% currently going to do 86 epochs
# At minibatch 32600, batch loss 0.014625, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.034205, batch error rate 1.000000%
# At minibatch 32800, batch loss 0.053284, batch error rate 2.000000%
# At minibatch 32900, batch loss 0.030057, batch error rate 1.000000%
# At minibatch 33000, batch loss 0.020693, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.022300% currently going to do 86 epochs
# At minibatch 33100, batch loss 0.031947, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.024473, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.028370, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.028886, batch error rate 1.000000%
# At minibatch 33500, batch loss 0.027768, batch error rate 1.000000%
# After epoch 67: valid_err_rate: 0.022200% currently going to do 86 epochs
# At minibatch 33600, batch loss 0.021800, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.046214, batch error rate 1.000000%
# At minibatch 33800, batch loss 0.050121, batch error rate 1.000000%
# At minibatch 33900, batch loss 0.039691, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.017501, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.023100% currently going to do 86 epochs
# At minibatch 34100, batch loss 0.017511, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.023447, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.084265, batch error rate 1.000000%
# At minibatch 34400, batch loss 0.026903, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.136613, batch error rate 3.000000%
# After epoch 69: valid_err_rate: 0.024100% currently going to do 86 epochs
# At minibatch 34600, batch loss 0.025626, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.011862, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.049195, batch error rate 1.000000%
# At minibatch 34900, batch loss 0.019053, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.024500, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.022800% currently going to do 86 epochs
# At minibatch 35100, batch loss 0.024008, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.026792, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.021835, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.029646, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.037191, batch error rate 1.000000%
# After epoch 71: valid_err_rate: 0.021400% currently going to do 107 epochs
# At minibatch 35600, batch loss 0.022922, batch error rate 1.000000%
# At minibatch 35700, batch loss 0.109264, batch error rate 2.000000%
# At minibatch 35800, batch loss 0.032053, batch error rate 0.000000%
# At minibatch 35900, batch loss 0.023554, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.054033, batch error rate 1.000000%
# After epoch 72: valid_err_rate: 0.023100% currently going to do 107 epochs
# At minibatch 36100, batch loss 0.029841, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.022731, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.028458, batch error rate 1.000000%
# At minibatch 36400, batch loss 0.021791, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.030915, batch error rate 1.000000%
# After epoch 73: valid_err_rate: 0.023400% currently going to do 107 epochs
# At minibatch 36600, batch loss 0.028699, batch error rate 1.000000%
# At minibatch 36700, batch loss 0.023499, batch error rate 1.000000%
# At minibatch 36800, batch loss 0.042486, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.035002, batch error rate 1.000000%
# At minibatch 37000, batch loss 0.021649, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.022600% currently going to do 107 epochs
# At minibatch 37100, batch loss 0.016200, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.018507, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.027775, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.043328, batch error rate 1.000000%
# At minibatch 37500, batch loss 0.048468, batch error rate 2.000000%
# After epoch 75: valid_err_rate: 0.021400% currently going to do 107 epochs
# At minibatch 37600, batch loss 0.026932, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.016104, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.026713, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.011520, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.028951, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.022800% currently going to do 107 epochs
# At minibatch 38100, batch loss 0.041885, batch error rate 1.000000%
# At minibatch 38200, batch loss 0.030468, batch error rate 1.000000%
# At minibatch 38300, batch loss 0.013702, batch error rate 0.000000%
# At minibatch 38400, batch loss 0.041291, batch error rate 1.000000%
# At minibatch 38500, batch loss 0.023968, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.021600% currently going to do 107 epochs
# At minibatch 38600, batch loss 0.035507, batch error rate 1.000000%
# At minibatch 38700, batch loss 0.016931, batch error rate 0.000000%
# At minibatch 38800, batch loss 0.016978, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.044618, batch error rate 1.000000%
# At minibatch 39000, batch loss 0.029431, batch error rate 1.000000%
# After epoch 78: valid_err_rate: 0.021300% currently going to do 118 epochs
# At minibatch 39100, batch loss 0.026532, batch error rate 1.000000%
# At minibatch 39200, batch loss 0.026304, batch error rate 1.000000%
# At minibatch 39300, batch loss 0.042115, batch error rate 1.000000%
# At minibatch 39400, batch loss 0.021253, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.038570, batch error rate 0.000000%
# After epoch 79: valid_err_rate: 0.021300% currently going to do 118 epochs
# At minibatch 39600, batch loss 0.018136, batch error rate 0.000000%
# At minibatch 39700, batch loss 0.028472, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.017912, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.024511, batch error rate 0.000000%
# At minibatch 40000, batch loss 0.018252, batch error rate 0.000000%
# After epoch 80: valid_err_rate: 0.021800% currently going to do 118 epochs
# At minibatch 40100, batch loss 0.013654, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.059722, batch error rate 3.000000%
# At minibatch 40300, batch loss 0.023886, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.021595, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.018393, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 0.021900% currently going to do 118 epochs
# At minibatch 40600, batch loss 0.038741, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.023926, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.030540, batch error rate 1.000000%
# At minibatch 40900, batch loss 0.021014, batch error rate 0.000000%
# At minibatch 41000, batch loss 0.022323, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.021600% currently going to do 118 epochs
# At minibatch 41100, batch loss 0.033443, batch error rate 1.000000%
# At minibatch 41200, batch loss 0.061532, batch error rate 1.000000%
# At minibatch 41300, batch loss 0.032798, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.068728, batch error rate 1.000000%
# At minibatch 41500, batch loss 0.022179, batch error rate 0.000000%
# After epoch 83: valid_err_rate: 0.021100% currently going to do 125 epochs
# At minibatch 41600, batch loss 0.014697, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.027010, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.025060, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.044703, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.017397, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.021800% currently going to do 125 epochs
# At minibatch 42100, batch loss 0.034165, batch error rate 1.000000%
# At minibatch 42200, batch loss 0.017154, batch error rate 0.000000%
# At minibatch 42300, batch loss 0.019346, batch error rate 0.000000%
# At minibatch 42400, batch loss 0.031573, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.041399, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.021900% currently going to do 125 epochs
# At minibatch 42600, batch loss 0.033690, batch error rate 1.000000%
# At minibatch 42700, batch loss 0.022358, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.021034, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.036341, batch error rate 1.000000%
# At minibatch 43000, batch loss 0.030704, batch error rate 1.000000%
# After epoch 86: valid_err_rate: 0.020400% currently going to do 130 epochs
# At minibatch 43100, batch loss 0.014538, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.027303, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.034081, batch error rate 1.000000%
# At minibatch 43400, batch loss 0.009236, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.028894, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.020600% currently going to do 130 epochs
# At minibatch 43600, batch loss 0.052146, batch error rate 3.000000%
# At minibatch 43700, batch loss 0.031297, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.033667, batch error rate 1.000000%
# At minibatch 43900, batch loss 0.018043, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.037710, batch error rate 1.000000%
# After epoch 88: valid_err_rate: 0.022000% currently going to do 130 epochs
# At minibatch 44100, batch loss 0.023520, batch error rate 0.000000%
# At minibatch 44200, batch loss 0.024991, batch error rate 0.000000%
# At minibatch 44300, batch loss 0.051898, batch error rate 2.000000%
# At minibatch 44400, batch loss 0.018379, batch error rate 0.000000%
# At minibatch 44500, batch loss 0.024140, batch error rate 0.000000%
# After epoch 89: valid_err_rate: 0.020600% currently going to do 130 epochs
# At minibatch 44600, batch loss 0.032646, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.020675, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.029220, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.023326, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.075201, batch error rate 1.000000%
# After epoch 90: valid_err_rate: 0.021400% currently going to do 130 epochs
# At minibatch 45100, batch loss 0.032236, batch error rate 1.000000%
# At minibatch 45200, batch loss 0.028708, batch error rate 1.000000%
# At minibatch 45300, batch loss 0.029338, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.017501, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.015446, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.022800% currently going to do 130 epochs
# At minibatch 45600, batch loss 0.021364, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.040652, batch error rate 1.000000%
# At minibatch 45800, batch loss 0.012977, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.018294, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.036806, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.021900% currently going to do 130 epochs
# At minibatch 46100, batch loss 0.013377, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.026052, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.024131, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.026306, batch error rate 1.000000%
# At minibatch 46500, batch loss 0.048655, batch error rate 2.000000%
# After epoch 93: valid_err_rate: 0.023300% currently going to do 130 epochs
# At minibatch 46600, batch loss 0.029959, batch error rate 1.000000%
# At minibatch 46700, batch loss 0.014840, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.021780, batch error rate 0.000000%
# At minibatch 46900, batch loss 0.028135, batch error rate 1.000000%
# At minibatch 47000, batch loss 0.015476, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.021700% currently going to do 130 epochs
# At minibatch 47100, batch loss 0.024361, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.034990, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.023576, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.017391, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.014230, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.021300% currently going to do 130 epochs
# At minibatch 47600, batch loss 0.021850, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.011262, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.021897, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.034625, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.022838, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.020500% currently going to do 130 epochs
# At minibatch 48100, batch loss 0.029142, batch error rate 0.000000%
# At minibatch 48200, batch loss 0.029810, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.037041, batch error rate 2.000000%
# At minibatch 48400, batch loss 0.025007, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.034919, batch error rate 1.000000%
# After epoch 97: valid_err_rate: 0.021700% currently going to do 130 epochs
# At minibatch 48600, batch loss 0.022221, batch error rate 1.000000%
# At minibatch 48700, batch loss 0.030110, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.039131, batch error rate 1.000000%
# At minibatch 48900, batch loss 0.011992, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.016259, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.021000% currently going to do 130 epochs
# At minibatch 49100, batch loss 0.023547, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.029664, batch error rate 1.000000%
# At minibatch 49300, batch loss 0.021973, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.036894, batch error rate 1.000000%
# At minibatch 49500, batch loss 0.016609, batch error rate 0.000000%
# After epoch 99: valid_err_rate: 0.019500% currently going to do 149 epochs
# At minibatch 49600, batch loss 0.015206, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.047883, batch error rate 2.000000%
# At minibatch 49800, batch loss 0.027603, batch error rate 0.000000%
# At minibatch 49900, batch loss 0.027339, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.024931, batch error rate 1.000000%
# After epoch 100: valid_err_rate: 0.020700% currently going to do 149 epochs
# At minibatch 50100, batch loss 0.027507, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.029802, batch error rate 1.000000%
# At minibatch 50300, batch loss 0.011332, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.016361, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.020446, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.021000% currently going to do 149 epochs
# At minibatch 50600, batch loss 0.025359, batch error rate 0.000000%
# At minibatch 50700, batch loss 0.015100, batch error rate 0.000000%
# At minibatch 50800, batch loss 0.017644, batch error rate 0.000000%
# At minibatch 50900, batch loss 0.027745, batch error rate 0.000000%
# At minibatch 51000, batch loss 0.031776, batch error rate 1.000000%
# After epoch 102: valid_err_rate: 0.022200% currently going to do 149 epochs
# At minibatch 51100, batch loss 0.018956, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.016117, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.023323, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.016582, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.018511, batch error rate 0.000000%
# After epoch 103: valid_err_rate: 0.020400% currently going to do 149 epochs
# At minibatch 51600, batch loss 0.029359, batch error rate 0.000000%
# At minibatch 51700, batch loss 0.020424, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.023285, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.040208, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.033840, batch error rate 1.000000%
# After epoch 104: valid_err_rate: 0.021000% currently going to do 149 epochs
# At minibatch 52100, batch loss 0.016780, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.023927, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.093376, batch error rate 2.000000%
# At minibatch 52400, batch loss 0.020592, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.052654, batch error rate 1.000000%
# After epoch 105: valid_err_rate: 0.020900% currently going to do 149 epochs
# At minibatch 52600, batch loss 0.019851, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.020835, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.014752, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.019092, batch error rate 0.000000%
# At minibatch 53000, batch loss 0.015750, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.020500% currently going to do 149 epochs
# At minibatch 53100, batch loss 0.024780, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.030219, batch error rate 1.000000%
# At minibatch 53300, batch loss 0.034535, batch error rate 0.000000%
# At minibatch 53400, batch loss 0.017512, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.034019, batch error rate 1.000000%
# After epoch 107: valid_err_rate: 0.020400% currently going to do 149 epochs
# At minibatch 53600, batch loss 0.029858, batch error rate 1.000000%
# At minibatch 53700, batch loss 0.031020, batch error rate 1.000000%
# At minibatch 53800, batch loss 0.025238, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.032417, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.011715, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.020500% currently going to do 149 epochs
# At minibatch 54100, batch loss 0.030226, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.028549, batch error rate 0.000000%
# At minibatch 54300, batch loss 0.013045, batch error rate 0.000000%
# At minibatch 54400, batch loss 0.024609, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.029401, batch error rate 1.000000%
# After epoch 109: valid_err_rate: 0.021500% currently going to do 149 epochs
# At minibatch 54600, batch loss 0.054319, batch error rate 1.000000%
# At minibatch 54700, batch loss 0.020672, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.026919, batch error rate 1.000000%
# At minibatch 54900, batch loss 0.019448, batch error rate 0.000000%
# At minibatch 55000, batch loss 0.010632, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.020800% currently going to do 149 epochs
# At minibatch 55100, batch loss 0.021624, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.022395, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.037126, batch error rate 1.000000%
# At minibatch 55400, batch loss 0.032077, batch error rate 0.000000%
# At minibatch 55500, batch loss 0.010206, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.021100% currently going to do 149 epochs
# At minibatch 55600, batch loss 0.020653, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.015094, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.016451, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.019634, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.018713, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.019600% currently going to do 149 epochs
# At minibatch 56100, batch loss 0.030090, batch error rate 0.000000%
# At minibatch 56200, batch loss 0.022169, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.018248, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.025825, batch error rate 1.000000%
# At minibatch 56500, batch loss 0.024929, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.021300% currently going to do 149 epochs
# At minibatch 56600, batch loss 0.034956, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.019598, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.014175, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.025197, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.036319, batch error rate 1.000000%
# After epoch 114: valid_err_rate: 0.020100% currently going to do 149 epochs
# At minibatch 57100, batch loss 0.014958, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.022991, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.017197, batch error rate 0.000000%
# At minibatch 57400, batch loss 0.034771, batch error rate 1.000000%
# At minibatch 57500, batch loss 0.038683, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.021900% currently going to do 149 epochs
# At minibatch 57600, batch loss 0.032372, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.027930, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.038746, batch error rate 1.000000%
# At minibatch 57900, batch loss 0.021567, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.042780, batch error rate 1.000000%
# After epoch 116: valid_err_rate: 0.020800% currently going to do 149 epochs
# At minibatch 58100, batch loss 0.021961, batch error rate 0.000000%
# At minibatch 58200, batch loss 0.023217, batch error rate 0.000000%
# At minibatch 58300, batch loss 0.033239, batch error rate 0.000000%
# At minibatch 58400, batch loss 0.009808, batch error rate 0.000000%
# At minibatch 58500, batch loss 0.034817, batch error rate 1.000000%
# After epoch 117: valid_err_rate: 0.020500% currently going to do 149 epochs
# At minibatch 58600, batch loss 0.023302, batch error rate 0.000000%
# At minibatch 58700, batch loss 0.023893, batch error rate 1.000000%
# At minibatch 58800, batch loss 0.023267, batch error rate 1.000000%
# At minibatch 58900, batch loss 0.016907, batch error rate 0.000000%
# At minibatch 59000, batch loss 0.038693, batch error rate 0.000000%
# After epoch 118: valid_err_rate: 0.020300% currently going to do 149 epochs
# At minibatch 59100, batch loss 0.043296, batch error rate 1.000000%
# At minibatch 59200, batch loss 0.027750, batch error rate 0.000000%
# At minibatch 59300, batch loss 0.028174, batch error rate 1.000000%
# At minibatch 59400, batch loss 0.019628, batch error rate 0.000000%
# At minibatch 59500, batch loss 0.036028, batch error rate 0.000000%
# After epoch 119: valid_err_rate: 0.019800% currently going to do 149 epochs
# At minibatch 59600, batch loss 0.016771, batch error rate 0.000000%
# At minibatch 59700, batch loss 0.037640, batch error rate 1.000000%
# At minibatch 59800, batch loss 0.013221, batch error rate 0.000000%
# At minibatch 59900, batch loss 0.025346, batch error rate 0.000000%
# At minibatch 60000, batch loss 0.029664, batch error rate 1.000000%
# After epoch 120: valid_err_rate: 0.020200% currently going to do 149 epochs
# At minibatch 60100, batch loss 0.017906, batch error rate 0.000000%
# At minibatch 60200, batch loss 0.036453, batch error rate 0.000000%
# At minibatch 60300, batch loss 0.022391, batch error rate 0.000000%
# At minibatch 60400, batch loss 0.020036, batch error rate 0.000000%
# At minibatch 60500, batch loss 0.036080, batch error rate 1.000000%
# After epoch 121: valid_err_rate: 0.021200% currently going to do 149 epochs
# At minibatch 60600, batch loss 0.040520, batch error rate 0.000000%
# At minibatch 60700, batch loss 0.022915, batch error rate 0.000000%
# At minibatch 60800, batch loss 0.027788, batch error rate 0.000000%
# At minibatch 60900, batch loss 0.031842, batch error rate 1.000000%
# At minibatch 61000, batch loss 0.010085, batch error rate 0.000000%
# After epoch 122: valid_err_rate: 0.021500% currently going to do 149 epochs
# At minibatch 61100, batch loss 0.011919, batch error rate 0.000000%
# At minibatch 61200, batch loss 0.017478, batch error rate 0.000000%
# At minibatch 61300, batch loss 0.025792, batch error rate 1.000000%
# At minibatch 61400, batch loss 0.036393, batch error rate 1.000000%
# At minibatch 61500, batch loss 0.041339, batch error rate 0.000000%
# After epoch 123: valid_err_rate: 0.020200% currently going to do 149 epochs
# At minibatch 61600, batch loss 0.051385, batch error rate 2.000000%
# At minibatch 61700, batch loss 0.029542, batch error rate 0.000000%
# At minibatch 61800, batch loss 0.025926, batch error rate 0.000000%
# At minibatch 61900, batch loss 0.015663, batch error rate 0.000000%
# At minibatch 62000, batch loss 0.022875, batch error rate 0.000000%
# After epoch 124: valid_err_rate: 0.020800% currently going to do 149 epochs
# At minibatch 62100, batch loss 0.024563, batch error rate 0.000000%
# At minibatch 62200, batch loss 0.026664, batch error rate 1.000000%
# At minibatch 62300, batch loss 0.026358, batch error rate 0.000000%
# At minibatch 62400, batch loss 0.023592, batch error rate 0.000000%
# At minibatch 62500, batch loss 0.010819, batch error rate 0.000000%
# After epoch 125: valid_err_rate: 0.021500% currently going to do 149 epochs
# At minibatch 62600, batch loss 0.020264, batch error rate 0.000000%
# At minibatch 62700, batch loss 0.021090, batch error rate 0.000000%
# At minibatch 62800, batch loss 0.033016, batch error rate 1.000000%
# At minibatch 62900, batch loss 0.020052, batch error rate 0.000000%
# At minibatch 63000, batch loss 0.019931, batch error rate 0.000000%
# After epoch 126: valid_err_rate: 0.020400% currently going to do 149 epochs
# At minibatch 63100, batch loss 0.015893, batch error rate 0.000000%
# At minibatch 63200, batch loss 0.025382, batch error rate 0.000000%
# At minibatch 63300, batch loss 0.014762, batch error rate 0.000000%
# At minibatch 63400, batch loss 0.018432, batch error rate 0.000000%
# At minibatch 63500, batch loss 0.014948, batch error rate 0.000000%
# After epoch 127: valid_err_rate: 0.021500% currently going to do 149 epochs
# At minibatch 63600, batch loss 0.015564, batch error rate 0.000000%
# At minibatch 63700, batch loss 0.052801, batch error rate 2.000000%
# At minibatch 63800, batch loss 0.031621, batch error rate 0.000000%
# At minibatch 63900, batch loss 0.016353, batch error rate 0.000000%
# At minibatch 64000, batch loss 0.020630, batch error rate 0.000000%
# After epoch 128: valid_err_rate: 0.021500% currently going to do 149 epochs
# At minibatch 64100, batch loss 0.015349, batch error rate 0.000000%
# At minibatch 64200, batch loss 0.017859, batch error rate 0.000000%
# At minibatch 64300, batch loss 0.022907, batch error rate 0.000000%
# At minibatch 64400, batch loss 0.013367, batch error rate 0.000000%
# At minibatch 64500, batch loss 0.020648, batch error rate 0.000000%
# After epoch 129: valid_err_rate: 0.020900% currently going to do 149 epochs
# At minibatch 64600, batch loss 0.019993, batch error rate 0.000000%
# At minibatch 64700, batch loss 0.030474, batch error rate 0.000000%
# At minibatch 64800, batch loss 0.019864, batch error rate 0.000000%
# At minibatch 64900, batch loss 0.034695, batch error rate 1.000000%
# At minibatch 65000, batch loss 0.018855, batch error rate 0.000000%
# After epoch 130: valid_err_rate: 0.021000% currently going to do 149 epochs
# At minibatch 65100, batch loss 0.024426, batch error rate 0.000000%
# At minibatch 65200, batch loss 0.015291, batch error rate 0.000000%
# At minibatch 65300, batch loss 0.013253, batch error rate 0.000000%
# At minibatch 65400, batch loss 0.017615, batch error rate 0.000000%
# Setting network parameters from after epoch 99
# Test error rate: 0.019900

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.019900000000000001

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.

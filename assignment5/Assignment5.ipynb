# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
from scipy.ndimage.filters import convolve

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here

            # ideas from http://stats.stackexchange.com/questions/47590/what-are-good-initial-weights-in-a-neural-network
            
            # if activation is hyperbolic tangent
            weight_init = Uniform(width = np.sqrt(6/(num_in + num_out)))
            #if activation is sigmoid
            #weight_init = Uniform(width = 4*np.sqrt(6/(num_in + num_out)))
            
            
            
            #weight_init = Uniform(width = 1/(np.sqrt(num_in)))
            
            #weight_init = IsotropicGaussian(std = 0.01)
            #weight_init = Constant(1.0)
            
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        #
        # TODO: fill in gradient computation
        #
        dLdX = self.W.T.dot(dLdY)
        
        return dLdX
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
# in_shape - (a,b,1,d)
# filter_shape - k

class ConvLayer(Layer):
    def __init__(self, in_shape, filter_size, num_filters, weight_init=None, bias_init=None, **kwargs):
        super(ConvLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here

            # ideas from http://stats.stackexchange.com/questions/47590/what-are-good-initial-weights-in-a-neural-network
            
            # if activation is hyperbolic tangent
            #weight_init = Uniform(width = np.sqrt(6/(num_in + num_out)))
            #if activation is sigmoid
            #weight_init = Uniform(width = 4*np.sqrt(6/(num_in + num_out)))
            
            
            
            #weight_init = Uniform(width = 1/(np.sqrt(num_in)))
            
            weight_init = IsotropicGaussian(std = 0.01)
            #weight_init = Constant(1.0)
            
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (filter_size, filter_size, num_filters,1))
        self.b = bias_init.generate(self.rng, (1,1,num_filters,1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = convolve(self.W, X, mode='constant') + b
        
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        #
        # TODO: fill in gradient computation
        #
        dLdX = self.W.T.dot(dLdY)
        
        return dLdX
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        return dLdY * (np.ones_like(Y) - Y**2)
    
class SigmoidLayer(Layer):
    def __init__(self, **kwargs):
        super(SigmoidLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = sigmoid(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        return dLdY * (Y * (np.ones_like(Y) - Y))

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            #print(X.shape)
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in range(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            #print(fp_context)
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            #print("dLdP shape: ", dLdP)
            dLdX = layer.bprop(dLdX, fp_context)
            
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in range(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print("Iter: %d, loss increased!!" % (i,))
        if (old_L - L)<tolerance:
            print("Tolerance level reached exiting")
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print("At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100))
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])


GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 1.219522, train error rate 82.000000%
# At iteration 1000, loss 0.052663, train error rate 2.000000%
# At iteration 2000, loss 0.044018, train error rate 2.000000%
# At iteration 3000, loss 0.041738, train error rate 1.333333%
# At iteration 4000, loss 0.040788, train error rate 1.333333%
# At iteration 5000, loss 0.040262, train error rate 1.333333%
# At iteration 6000, loss 0.039875, train error rate 1.333333%
# At iteration 7000, loss 0.039502, train error rate 1.333333%
# At iteration 8000, loss 0.039091, train error rate 1.333333%
# At iteration 9000, loss 0.038645, train error rate 1.333333%
# At iteration 10000, loss 0.038196, train error rate 1.333333%
# At iteration 11000, loss 0.037767, train error rate 1.333333%
# At iteration 12000, loss 0.037371, train error rate 1.333333%
# At iteration 13000, loss 0.037013, train error rate 1.333333%
# At iteration 14000, loss 0.036690, train error rate 1.333333%
# At iteration 15000, loss 0.036392, train error rate 1.333333%
# At iteration 16000, loss 0.036107, train error rate 1.333333%
# At iteration 17000, loss 0.035824, train error rate 1.333333%
# At iteration 18000, loss 0.035534, train error rate 1.333333%
# At iteration 19000, loss 0.035233, train error rate 1.333333%
# At iteration 20000, loss 0.034916, train error rate 1.333333%
# At iteration 21000, loss 0.034579, train error rate 1.333333%
# At iteration 22000, loss 0.034217, train error rate 1.333333%
# At iteration 23000, loss 0.033831, train error rate 1.333333%
# At iteration 24000, loss 0.033424, train error rate 1.333333%
# At iteration 25000, loss 0.033007, train error rate 1.333333%
# At iteration 26000, loss 0.032584, train error rate 1.333333%
# At iteration 27000, loss 0.032154, train error rate 1.333333%
# At iteration 28000, loss 0.031715, train error rate 1.333333%
# At iteration 29000, loss 0.031262, train error rate 1.333333%
# At iteration 30000, loss 0.030790, train error rate 1.333333%
# At iteration 31000, loss 0.030295, train error rate 1.333333%
# At iteration 32000, loss 0.029776, train error rate 1.333333%
# At iteration 33000, loss 0.029230, train error rate 1.333333%
# At iteration 34000, loss 0.028657, train error rate 1.333333%
# At iteration 35000, loss 0.028052, train error rate 1.333333%
# At iteration 36000, loss 0.027406, train error rate 1.333333%
# At iteration 37000, loss 0.026709, train error rate 1.333333%
# At iteration 38000, loss 0.025949, train error rate 1.333333%
# At iteration 39000, loss 0.025111, train error rate 1.333333%
# At iteration 40000, loss 0.024181, train error rate 1.333333%
# At iteration 41000, loss 0.023146, train error rate 1.333333%
# At iteration 42000, loss 0.021995, train error rate 1.333333%
# At iteration 43000, loss 0.020734, train error rate 1.333333%
# At iteration 44000, loss 0.019396, train error rate 1.333333%
# At iteration 45000, loss 0.018030, train error rate 1.333333%
# At iteration 46000, loss 0.016670, train error rate 0.666667%
# At iteration 47000, loss 0.015327, train error rate 0.666667%
# At iteration 48000, loss 0.013995, train error rate 0.666667%
# At iteration 49000, loss 0.012675, train error rate 0.000000%

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print("The streams return batches containing %s" % (mnist_train_stream.sources,))

print("Each trainin batch consits of a tuple containing:")
for element in next(mnist_train_stream.get_epoch_iterator()):
    print(" - an array of size %s containing %s" % (element.shape, element.dtype))
    
print("Validation/test batches consits of tuples containing:")
for element in next(mnist_test_stream.get_epoch_iterator()):
    print(" - an array of size %s containing %s" % (element.shape, element.dtype))
# Out:
# The streams return batches containing ('features', 'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %%
X,Y = next(mnist_train_stream.get_epoch_iterator())
imshow(X[:,2].reshape((28,28)), cmap='gray')

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def SGD(net, train_stream, validation_stream, test_stream, alp=(5e-1, 5e-3), gamma = 0.05, delta = 1e-1, lambd = 7e-3, epsilon = 5e-3):
    i=0
    e=0
    
    #initialize momentum variables
    #
    # TODO
    #
    # Hint: you need one valocity matrix for each parameter
    #velocities = [ for P in net.parameters]
    velocities = [np.zeros_like(P) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    train_erros = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = 3
    patience_expansion = 1.5
    
    val_error_rate = np.inf
    prev_val_error_rate = np.inf
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_erros.append((i,err_rate))
                if i % 100 == 0:
                    print("At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100))
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N == 'W':
                        #
                        # TODO: implement the weight decay addition to gradient
                        #
                        G += lambd*P
                    
                    #
                    # TODO: set a learning rate
                    #
                    # Hint, use the iteration counter i
                    alpha = alp[1] if i >= 10000 else alp[0]
                    
                    
                    #
                    # TODO: set the momentum constant 
                    # 
                    
                   
                    
                    #
                    # TODO: implement velocity update in momentum
                    #
                    old_V = V
                    V = epsilon * (G + old_V)
                    
                    #
                    # TODO: set a more sensible learning rule here,
                    # using your learning rate schedule and momentum
                    #
                    #!!!!! Need to modify the actual parameter here! 
                    P += -alpha * G + old_V
            # After an epoch compute validation error
            prev_val_error_rate = val_error_rate
            val_error_rate = compute_error_rate(net, validation_stream)
            
            if prev_val_error_rate >= val_error_rate:
                alpha *= (1 + gamma)
            elif (abs(prev_val_error_rate - val_error_rate) >= delta):
                alpha /= 1.5
                #gamma /= 1.5
            
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            print("After epoch %d: valid_err_rate: %f%% currently going to do %d epochs" %(
                e, val_error_rate, number_of_epochs))
            
    except KeyboardInterrupt:
        print("Setting network parameters from after epoch %d" %(best_params_epoch))
        net.parameters = best_params
        
        subplot(2,1,1)
        train_loss = np.array(train_loss)
        semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
        legend()
        
        subplot(2,1,2)
        train_erros = np.array(train_erros)
        plot(train_erros[:,0], train_erros[:,1], label='batch train error rate')
        validation_errors = np.array(validation_errors)
        plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
        ylim(0,0.2)
        legend()

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
# TODO: pick a network architecture here. The one below is just 
# softmax regression

net = FeedForwardNet([
        AffineLayer(784,500),
        ReLULayer(),
        AffineLayer(500,300),
        ReLULayer(),
        AffineLayer(300,50),
        ReLULayer(),
        AffineLayer(50,10),
        SoftMaxLayer()
        ])


SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
   alp=(4e-2, 5e-3),
   gamma = 0.05,
   delta = 1e-1,
   lambd = 1e-3,
   epsilon = 1e-10)

print("Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), ))
# Out:
# At minibatch 100, batch loss 1.549965, batch error rate 54.000000%
# At minibatch 200, batch loss 0.899594, batch error rate 31.000000%
# At minibatch 300, batch loss 0.538193, batch error rate 13.000000%
# At minibatch 400, batch loss 0.372427, batch error rate 11.000000%
# At minibatch 500, batch loss 0.380205, batch error rate 11.000000%
# After epoch 1: valid_err_rate: 0.101500% currently going to do 3 epochs
# At minibatch 600, batch loss 0.237037, batch error rate 6.000000%
# At minibatch 700, batch loss 0.585689, batch error rate 16.000000%
# At minibatch 800, batch loss 0.303652, batch error rate 7.000000%
# At minibatch 900, batch loss 0.253674, batch error rate 11.000000%
# At minibatch 1000, batch loss 0.214279, batch error rate 7.000000%
# After epoch 2: valid_err_rate: 0.068400% currently going to do 4 epochs
# At minibatch 1100, batch loss 0.262294, batch error rate 7.000000%
# At minibatch 1200, batch loss 0.301563, batch error rate 11.000000%
# At minibatch 1300, batch loss 0.260097, batch error rate 8.000000%
# At minibatch 1400, batch loss 0.197064, batch error rate 6.000000%
# At minibatch 1500, batch loss 0.201231, batch error rate 6.000000%
# After epoch 3: valid_err_rate: 0.056600% currently going to do 5 epochs
# At minibatch 1600, batch loss 0.192209, batch error rate 5.000000%
# At minibatch 1700, batch loss 0.251177, batch error rate 9.000000%
# At minibatch 1800, batch loss 0.163768, batch error rate 7.000000%
# At minibatch 1900, batch loss 0.223205, batch error rate 7.000000%
# At minibatch 2000, batch loss 0.237074, batch error rate 8.000000%
# After epoch 4: valid_err_rate: 0.048200% currently going to do 7 epochs
# At minibatch 2100, batch loss 0.192638, batch error rate 5.000000%
# At minibatch 2200, batch loss 0.178255, batch error rate 4.000000%
# At minibatch 2300, batch loss 0.186653, batch error rate 5.000000%
# At minibatch 2400, batch loss 0.254708, batch error rate 7.000000%
# At minibatch 2500, batch loss 0.166999, batch error rate 5.000000%
# After epoch 5: valid_err_rate: 0.041300% currently going to do 8 epochs
# At minibatch 2600, batch loss 0.256489, batch error rate 9.000000%
# At minibatch 2700, batch loss 0.127806, batch error rate 5.000000%
# At minibatch 2800, batch loss 0.115468, batch error rate 2.000000%
# At minibatch 2900, batch loss 0.108403, batch error rate 3.000000%
# At minibatch 3000, batch loss 0.067168, batch error rate 1.000000%
# After epoch 6: valid_err_rate: 0.033800% currently going to do 10 epochs
# At minibatch 3100, batch loss 0.138175, batch error rate 4.000000%
# At minibatch 3200, batch loss 0.053313, batch error rate 2.000000%
# At minibatch 3300, batch loss 0.055604, batch error rate 2.000000%
# At minibatch 3400, batch loss 0.112904, batch error rate 3.000000%
# At minibatch 3500, batch loss 0.060647, batch error rate 2.000000%
# After epoch 7: valid_err_rate: 0.034300% currently going to do 10 epochs
# At minibatch 3600, batch loss 0.188779, batch error rate 6.000000%
# At minibatch 3700, batch loss 0.080357, batch error rate 3.000000%
# At minibatch 3800, batch loss 0.080639, batch error rate 3.000000%
# At minibatch 3900, batch loss 0.071693, batch error rate 3.000000%
# At minibatch 4000, batch loss 0.070668, batch error rate 3.000000%
# After epoch 8: valid_err_rate: 0.033100% currently going to do 13 epochs
# At minibatch 4100, batch loss 0.075367, batch error rate 2.000000%
# At minibatch 4200, batch loss 0.050674, batch error rate 1.000000%
# At minibatch 4300, batch loss 0.079162, batch error rate 3.000000%
# At minibatch 4400, batch loss 0.057373, batch error rate 1.000000%
# At minibatch 4500, batch loss 0.074608, batch error rate 2.000000%
# After epoch 9: valid_err_rate: 0.029100% currently going to do 14 epochs
# At minibatch 4600, batch loss 0.119788, batch error rate 5.000000%
# At minibatch 4700, batch loss 0.099998, batch error rate 4.000000%
# At minibatch 4800, batch loss 0.055544, batch error rate 3.000000%
# At minibatch 4900, batch loss 0.037854, batch error rate 1.000000%
# At minibatch 5000, batch loss 0.073725, batch error rate 4.000000%
# After epoch 10: valid_err_rate: 0.027300% currently going to do 16 epochs
# At minibatch 5100, batch loss 0.116314, batch error rate 4.000000%
# At minibatch 5200, batch loss 0.177128, batch error rate 2.000000%
# At minibatch 5300, batch loss 0.091427, batch error rate 4.000000%
# At minibatch 5400, batch loss 0.067862, batch error rate 2.000000%
# At minibatch 5500, batch loss 0.131876, batch error rate 3.000000%
# After epoch 11: valid_err_rate: 0.028600% currently going to do 16 epochs
# At minibatch 5600, batch loss 0.135282, batch error rate 6.000000%
# At minibatch 5700, batch loss 0.048853, batch error rate 2.000000%
# At minibatch 5800, batch loss 0.069359, batch error rate 3.000000%
# At minibatch 5900, batch loss 0.072454, batch error rate 2.000000%
# At minibatch 6000, batch loss 0.126914, batch error rate 2.000000%
# After epoch 12: valid_err_rate: 0.027800% currently going to do 16 epochs
# At minibatch 6100, batch loss 0.037236, batch error rate 0.000000%
# At minibatch 6200, batch loss 0.035331, batch error rate 1.000000%
# At minibatch 6300, batch loss 0.030805, batch error rate 0.000000%
# At minibatch 6400, batch loss 0.085578, batch error rate 3.000000%
# At minibatch 6500, batch loss 0.039505, batch error rate 1.000000%
# After epoch 13: valid_err_rate: 0.025000% currently going to do 20 epochs
# At minibatch 6600, batch loss 0.078069, batch error rate 4.000000%
# At minibatch 6700, batch loss 0.066334, batch error rate 3.000000%
# At minibatch 6800, batch loss 0.041783, batch error rate 2.000000%
# At minibatch 6900, batch loss 0.038815, batch error rate 1.000000%
# At minibatch 7000, batch loss 0.090282, batch error rate 3.000000%
# After epoch 14: valid_err_rate: 0.025100% currently going to do 20 epochs
# At minibatch 7100, batch loss 0.054639, batch error rate 1.000000%
# At minibatch 7200, batch loss 0.097847, batch error rate 3.000000%
# At minibatch 7300, batch loss 0.102501, batch error rate 4.000000%
# At minibatch 7400, batch loss 0.036634, batch error rate 1.000000%
# At minibatch 7500, batch loss 0.060958, batch error rate 2.000000%
# After epoch 15: valid_err_rate: 0.022100% currently going to do 23 epochs
# At minibatch 7600, batch loss 0.019530, batch error rate 0.000000%
# At minibatch 7700, batch loss 0.047582, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.045890, batch error rate 2.000000%
# At minibatch 7900, batch loss 0.032909, batch error rate 2.000000%
# At minibatch 8000, batch loss 0.080416, batch error rate 3.000000%
# After epoch 16: valid_err_rate: 0.026900% currently going to do 23 epochs
# At minibatch 8100, batch loss 0.029233, batch error rate 0.000000%
# At minibatch 8200, batch loss 0.028133, batch error rate 1.000000%
# At minibatch 8300, batch loss 0.017032, batch error rate 0.000000%
# At minibatch 8400, batch loss 0.061219, batch error rate 2.000000%
# At minibatch 8500, batch loss 0.088602, batch error rate 2.000000%
# After epoch 17: valid_err_rate: 0.029300% currently going to do 23 epochs
# At minibatch 8600, batch loss 0.044913, batch error rate 2.000000%
# At minibatch 8700, batch loss 0.017655, batch error rate 0.000000%
# At minibatch 8800, batch loss 0.039640, batch error rate 1.000000%
# At minibatch 8900, batch loss 0.023184, batch error rate 0.000000%
# At minibatch 9000, batch loss 0.031999, batch error rate 1.000000%
# After epoch 18: valid_err_rate: 0.026500% currently going to do 23 epochs
# At minibatch 9100, batch loss 0.027988, batch error rate 1.000000%
# At minibatch 9200, batch loss 0.117087, batch error rate 4.000000%
# At minibatch 9300, batch loss 0.036628, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.020516, batch error rate 0.000000%
# At minibatch 9500, batch loss 0.101094, batch error rate 1.000000%
# After epoch 19: valid_err_rate: 0.023700% currently going to do 23 epochs
# At minibatch 9600, batch loss 0.018509, batch error rate 0.000000%
# At minibatch 9700, batch loss 0.056298, batch error rate 3.000000%
# At minibatch 9800, batch loss 0.032766, batch error rate 1.000000%
# At minibatch 9900, batch loss 0.016254, batch error rate 0.000000%
# At minibatch 10000, batch loss 0.025863, batch error rate 0.000000%
# After epoch 20: valid_err_rate: 0.020500% currently going to do 31 epochs
# At minibatch 10100, batch loss 0.014092, batch error rate 0.000000%
# At minibatch 10200, batch loss 0.011535, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.028918, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.007172, batch error rate 0.000000%
# At minibatch 10500, batch loss 0.053068, batch error rate 1.000000%
# After epoch 21: valid_err_rate: 0.019100% currently going to do 32 epochs
# At minibatch 10600, batch loss 0.072593, batch error rate 3.000000%
# At minibatch 10700, batch loss 0.007934, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.008943, batch error rate 0.000000%
# At minibatch 10900, batch loss 0.031751, batch error rate 1.000000%
# At minibatch 11000, batch loss 0.015697, batch error rate 1.000000%
# After epoch 22: valid_err_rate: 0.019000% currently going to do 34 epochs
# At minibatch 11100, batch loss 0.011819, batch error rate 0.000000%
# At minibatch 11200, batch loss 0.025733, batch error rate 1.000000%
# At minibatch 11300, batch loss 0.018276, batch error rate 0.000000%
# At minibatch 11400, batch loss 0.030219, batch error rate 1.000000%
# At minibatch 11500, batch loss 0.041497, batch error rate 1.000000%
# After epoch 23: valid_err_rate: 0.019300% currently going to do 34 epochs
# At minibatch 11600, batch loss 0.043454, batch error rate 1.000000%
# At minibatch 11700, batch loss 0.015975, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.020821, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.009192, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.013058, batch error rate 0.000000%
# After epoch 24: valid_err_rate: 0.018800% currently going to do 37 epochs
# At minibatch 12100, batch loss 0.015806, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.012408, batch error rate 0.000000%
# At minibatch 12300, batch loss 0.006259, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.017590, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.007152, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.019500% currently going to do 37 epochs
# At minibatch 12600, batch loss 0.036689, batch error rate 1.000000%
# At minibatch 12700, batch loss 0.062536, batch error rate 3.000000%
# At minibatch 12800, batch loss 0.030785, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.016256, batch error rate 0.000000%
# At minibatch 13000, batch loss 0.024257, batch error rate 0.000000%
# After epoch 26: valid_err_rate: 0.018300% currently going to do 40 epochs
# At minibatch 13100, batch loss 0.013340, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.007933, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.021982, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.025708, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.022413, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.018500% currently going to do 40 epochs
# At minibatch 13600, batch loss 0.014384, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.029869, batch error rate 1.000000%
# At minibatch 13800, batch loss 0.014404, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.017372, batch error rate 0.000000%
# At minibatch 14000, batch loss 0.010840, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.019100% currently going to do 40 epochs
# At minibatch 14100, batch loss 0.029088, batch error rate 1.000000%
# At minibatch 14200, batch loss 0.019080, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.014833, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.021856, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.022333, batch error rate 1.000000%
# After epoch 29: valid_err_rate: 0.018400% currently going to do 40 epochs
# At minibatch 14600, batch loss 0.010477, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.019929, batch error rate 0.000000%
# At minibatch 14800, batch loss 0.037873, batch error rate 1.000000%
# At minibatch 14900, batch loss 0.031913, batch error rate 1.000000%
# At minibatch 15000, batch loss 0.016769, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.019100% currently going to do 40 epochs
# At minibatch 15100, batch loss 0.037554, batch error rate 1.000000%
# At minibatch 15200, batch loss 0.044637, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.021905, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.006525, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.043885, batch error rate 1.000000%
# After epoch 31: valid_err_rate: 0.018600% currently going to do 40 epochs
# At minibatch 15600, batch loss 0.022702, batch error rate 1.000000%
# At minibatch 15700, batch loss 0.016427, batch error rate 0.000000%
# At minibatch 15800, batch loss 0.005135, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.090233, batch error rate 1.000000%
# At minibatch 16000, batch loss 0.015804, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.019100% currently going to do 40 epochs
# At minibatch 16100, batch loss 0.008899, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.017575, batch error rate 1.000000%
# At minibatch 16300, batch loss 0.029069, batch error rate 1.000000%
# At minibatch 16400, batch loss 0.016853, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.044983, batch error rate 1.000000%
# After epoch 33: valid_err_rate: 0.018500% currently going to do 40 epochs
# At minibatch 16600, batch loss 0.040986, batch error rate 2.000000%
# At minibatch 16700, batch loss 0.008998, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.081940, batch error rate 1.000000%
# At minibatch 16900, batch loss 0.012463, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.023222, batch error rate 0.000000%
# After epoch 34: valid_err_rate: 0.018600% currently going to do 40 epochs
# At minibatch 17100, batch loss 0.015460, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.019436, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.014012, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.013059, batch error rate 1.000000%
# At minibatch 17500, batch loss 0.005570, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.018300% currently going to do 40 epochs
# At minibatch 17600, batch loss 0.035469, batch error rate 1.000000%
# At minibatch 17700, batch loss 0.011100, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.019180, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.009298, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.003874, batch error rate 0.000000%
# After epoch 36: valid_err_rate: 0.018200% currently going to do 55 epochs
# At minibatch 18100, batch loss 0.008042, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.029443, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.018323, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.014101, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.023945, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.018100% currently going to do 56 epochs
# At minibatch 18600, batch loss 0.025236, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.014014, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.035085, batch error rate 1.000000%
# At minibatch 18900, batch loss 0.012045, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.012992, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.018500% currently going to do 56 epochs
# At minibatch 19100, batch loss 0.014222, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.010127, batch error rate 0.000000%
# At minibatch 19300, batch loss 0.017212, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.008741, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.021770, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.018400% currently going to do 56 epochs
# At minibatch 19600, batch loss 0.013438, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.017354, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.025939, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.011175, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.004991, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.019100% currently going to do 56 epochs
# At minibatch 20100, batch loss 0.048604, batch error rate 1.000000%
# At minibatch 20200, batch loss 0.025071, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.037745, batch error rate 3.000000%
# At minibatch 20400, batch loss 0.020449, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.009723, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.018900% currently going to do 56 epochs
# At minibatch 20600, batch loss 0.059818, batch error rate 1.000000%
# At minibatch 20700, batch loss 0.043518, batch error rate 1.000000%
# At minibatch 20800, batch loss 0.013867, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.035389, batch error rate 1.000000%
# At minibatch 21000, batch loss 0.010808, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.018200% currently going to do 56 epochs
# At minibatch 21100, batch loss 0.011389, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.009741, batch error rate 0.000000%
# At minibatch 21300, batch loss 0.046241, batch error rate 2.000000%
# At minibatch 21400, batch loss 0.056319, batch error rate 2.000000%
# At minibatch 21500, batch loss 0.004923, batch error rate 0.000000%
# After epoch 43: valid_err_rate: 0.017900% currently going to do 65 epochs
# At minibatch 21600, batch loss 0.018553, batch error rate 0.000000%
# At minibatch 21700, batch loss 0.014023, batch error rate 0.000000%
# At minibatch 21800, batch loss 0.010609, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.038448, batch error rate 1.000000%
# At minibatch 22000, batch loss 0.018228, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.018200% currently going to do 65 epochs
# At minibatch 22100, batch loss 0.015409, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.024322, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.009102, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.025348, batch error rate 0.000000%
# At minibatch 22500, batch loss 0.015955, batch error rate 1.000000%
# After epoch 45: valid_err_rate: 0.018700% currently going to do 65 epochs
# At minibatch 22600, batch loss 0.021865, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.029343, batch error rate 1.000000%
# At minibatch 22800, batch loss 0.007190, batch error rate 0.000000%
# At minibatch 22900, batch loss 0.006628, batch error rate 0.000000%
# At minibatch 23000, batch loss 0.015602, batch error rate 1.000000%
# After epoch 46: valid_err_rate: 0.018300% currently going to do 65 epochs
# At minibatch 23100, batch loss 0.015053, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.014109, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.033172, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.023851, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.013726, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.018500% currently going to do 65 epochs
# At minibatch 23600, batch loss 0.027146, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.014794, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.016841, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.028271, batch error rate 1.000000%
# At minibatch 24000, batch loss 0.016726, batch error rate 1.000000%
# After epoch 48: valid_err_rate: 0.017900% currently going to do 65 epochs
# At minibatch 24100, batch loss 0.018609, batch error rate 1.000000%
# At minibatch 24200, batch loss 0.017023, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.025905, batch error rate 2.000000%
# At minibatch 24400, batch loss 0.020702, batch error rate 1.000000%
# At minibatch 24500, batch loss 0.025427, batch error rate 1.000000%
# After epoch 49: valid_err_rate: 0.018300% currently going to do 65 epochs
# At minibatch 24600, batch loss 0.008646, batch error rate 0.000000%
# At minibatch 24700, batch loss 0.018917, batch error rate 1.000000%
# At minibatch 24800, batch loss 0.020091, batch error rate 1.000000%
# At minibatch 24900, batch loss 0.022357, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.010191, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.017900% currently going to do 65 epochs
# At minibatch 25100, batch loss 0.004931, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.010602, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.011933, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.016775, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.016877, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.018500% currently going to do 65 epochs
# At minibatch 25600, batch loss 0.011646, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.010526, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.007957, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.009475, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.005763, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.017800% currently going to do 79 epochs
# At minibatch 26100, batch loss 0.085075, batch error rate 2.000000%
# At minibatch 26200, batch loss 0.010667, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.008289, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.044422, batch error rate 2.000000%
# At minibatch 26500, batch loss 0.013199, batch error rate 0.000000%
# After epoch 53: valid_err_rate: 0.018100% currently going to do 79 epochs
# At minibatch 26600, batch loss 0.012453, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.005562, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.020019, batch error rate 0.000000%
# At minibatch 26900, batch loss 0.015645, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.020771, batch error rate 1.000000%
# After epoch 54: valid_err_rate: 0.017500% currently going to do 82 epochs
# At minibatch 27100, batch loss 0.017578, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.015471, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.020094, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.013047, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.009649, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.017700% currently going to do 82 epochs
# At minibatch 27600, batch loss 0.031174, batch error rate 1.000000%
# At minibatch 27700, batch loss 0.009600, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.018073, batch error rate 1.000000%
# At minibatch 27900, batch loss 0.030216, batch error rate 1.000000%
# At minibatch 28000, batch loss 0.025843, batch error rate 1.000000%
# After epoch 56: valid_err_rate: 0.018300% currently going to do 82 epochs
# At minibatch 28100, batch loss 0.028699, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.010338, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.031142, batch error rate 2.000000%
# At minibatch 28400, batch loss 0.027088, batch error rate 1.000000%
# At minibatch 28500, batch loss 0.010471, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.018200% currently going to do 82 epochs
# At minibatch 28600, batch loss 0.014020, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.015352, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.020289, batch error rate 0.000000%
# At minibatch 28900, batch loss 0.022138, batch error rate 1.000000%
# At minibatch 29000, batch loss 0.012997, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.018300% currently going to do 82 epochs
# At minibatch 29100, batch loss 0.011070, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.017258, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.015810, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.009564, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.027040, batch error rate 1.000000%
# After epoch 59: valid_err_rate: 0.017800% currently going to do 82 epochs
# At minibatch 29600, batch loss 0.008986, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.013902, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.010656, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.010522, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.049780, batch error rate 2.000000%
# After epoch 60: valid_err_rate: 0.018000% currently going to do 82 epochs
# At minibatch 30100, batch loss 0.020184, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.029558, batch error rate 1.000000%
# At minibatch 30300, batch loss 0.006628, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.010598, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.028077, batch error rate 1.000000%
# After epoch 61: valid_err_rate: 0.018000% currently going to do 82 epochs
# At minibatch 30600, batch loss 0.011562, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.015318, batch error rate 0.000000%
# At minibatch 30800, batch loss 0.010766, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.053428, batch error rate 1.000000%
# At minibatch 31000, batch loss 0.006898, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.017700% currently going to do 82 epochs
# At minibatch 31100, batch loss 0.008197, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.025045, batch error rate 1.000000%
# At minibatch 31300, batch loss 0.023737, batch error rate 1.000000%
# At minibatch 31400, batch loss 0.008780, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.019473, batch error rate 1.000000%
# After epoch 63: valid_err_rate: 0.017400% currently going to do 95 epochs
# At minibatch 31600, batch loss 0.027572, batch error rate 2.000000%
# At minibatch 31700, batch loss 0.032718, batch error rate 1.000000%
# At minibatch 31800, batch loss 0.012952, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.016851, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.013022, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.017400% currently going to do 95 epochs
# At minibatch 32100, batch loss 0.018275, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.032895, batch error rate 2.000000%
# At minibatch 32300, batch loss 0.031299, batch error rate 1.000000%
# At minibatch 32400, batch loss 0.011831, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.007307, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.017900% currently going to do 95 epochs
# At minibatch 32600, batch loss 0.018311, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.014931, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.006563, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.016088, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.024774, batch error rate 1.000000%
# After epoch 66: valid_err_rate: 0.018500% currently going to do 95 epochs
# At minibatch 33100, batch loss 0.022558, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.010428, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.012181, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.025047, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.014907, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.017800% currently going to do 95 epochs
# At minibatch 33600, batch loss 0.003766, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.014664, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.014397, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.007721, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.009436, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.017700% currently going to do 95 epochs
# At minibatch 34100, batch loss 0.030818, batch error rate 1.000000%
# At minibatch 34200, batch loss 0.008968, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.027858, batch error rate 1.000000%
# At minibatch 34400, batch loss 0.008432, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.008041, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.017800% currently going to do 95 epochs
# At minibatch 34600, batch loss 0.021405, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.006208, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.010361, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.014691, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.010430, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.017300% currently going to do 106 epochs
# At minibatch 35100, batch loss 0.026457, batch error rate 1.000000%
# At minibatch 35200, batch loss 0.010779, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.005311, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.036378, batch error rate 1.000000%
# At minibatch 35500, batch loss 0.021692, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.017700% currently going to do 106 epochs
# At minibatch 35600, batch loss 0.034960, batch error rate 1.000000%
# At minibatch 35700, batch loss 0.012309, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.013139, batch error rate 0.000000%
# At minibatch 35900, batch loss 0.007526, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.019693, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.017700% currently going to do 106 epochs
# At minibatch 36100, batch loss 0.008417, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.008511, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.011507, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.020804, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.068956, batch error rate 1.000000%
# After epoch 73: valid_err_rate: 0.017100% currently going to do 110 epochs
# At minibatch 36600, batch loss 0.018616, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.007643, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.017068, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.007575, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.008738, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.017200% currently going to do 110 epochs
# At minibatch 37100, batch loss 0.027604, batch error rate 1.000000%
# At minibatch 37200, batch loss 0.011405, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.008707, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.020544, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.013472, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.017700% currently going to do 110 epochs
# At minibatch 37600, batch loss 0.013278, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.007106, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.006600, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.009018, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.031967, batch error rate 1.000000%
# After epoch 76: valid_err_rate: 0.017600% currently going to do 110 epochs
# At minibatch 38100, batch loss 0.030072, batch error rate 0.000000%
# At minibatch 38200, batch loss 0.011026, batch error rate 0.000000%
# At minibatch 38300, batch loss 0.009384, batch error rate 0.000000%
# At minibatch 38400, batch loss 0.003926, batch error rate 0.000000%
# At minibatch 38500, batch loss 0.012050, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.017100% currently going to do 110 epochs
# At minibatch 38600, batch loss 0.013499, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.005472, batch error rate 0.000000%
# At minibatch 38800, batch loss 0.012225, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.025288, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.015076, batch error rate 0.000000%
# After epoch 78: valid_err_rate: 0.017200% currently going to do 110 epochs
# At minibatch 39100, batch loss 0.009017, batch error rate 0.000000%
# At minibatch 39200, batch loss 0.017859, batch error rate 0.000000%
# At minibatch 39300, batch loss 0.030475, batch error rate 1.000000%
# At minibatch 39400, batch loss 0.020143, batch error rate 1.000000%
# At minibatch 39500, batch loss 0.007281, batch error rate 0.000000%
# After epoch 79: valid_err_rate: 0.017500% currently going to do 110 epochs
# At minibatch 39600, batch loss 0.013737, batch error rate 0.000000%
# At minibatch 39700, batch loss 0.014514, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.006417, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.009440, batch error rate 0.000000%
# At minibatch 40000, batch loss 0.007321, batch error rate 0.000000%
# After epoch 80: valid_err_rate: 0.017100% currently going to do 110 epochs
# At minibatch 40100, batch loss 0.015003, batch error rate 1.000000%
# At minibatch 40200, batch loss 0.012319, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.022663, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.012256, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.021874, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 0.017600% currently going to do 110 epochs
# At minibatch 40600, batch loss 0.006356, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.021525, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.008256, batch error rate 0.000000%
# At minibatch 40900, batch loss 0.022448, batch error rate 0.000000%
# At minibatch 41000, batch loss 0.017147, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.017700% currently going to do 110 epochs
# At minibatch 41100, batch loss 0.017270, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.015381, batch error rate 0.000000%
# At minibatch 41300, batch loss 0.007301, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.011815, batch error rate 0.000000%
# At minibatch 41500, batch loss 0.008151, batch error rate 0.000000%
# After epoch 83: valid_err_rate: 0.017700% currently going to do 110 epochs
# At minibatch 41600, batch loss 0.018845, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.012832, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.009997, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.011430, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.013175, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.017800% currently going to do 110 epochs
# At minibatch 42100, batch loss 0.017710, batch error rate 0.000000%
# At minibatch 42200, batch loss 0.013385, batch error rate 0.000000%
# At minibatch 42300, batch loss 0.016827, batch error rate 0.000000%
# At minibatch 42400, batch loss 0.023075, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.012533, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.017100% currently going to do 110 epochs
# At minibatch 42600, batch loss 0.011466, batch error rate 0.000000%
# At minibatch 42700, batch loss 0.025833, batch error rate 1.000000%
# At minibatch 42800, batch loss 0.005435, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.007100, batch error rate 0.000000%
# At minibatch 43000, batch loss 0.021211, batch error rate 0.000000%
# After epoch 86: valid_err_rate: 0.017800% currently going to do 110 epochs
# At minibatch 43100, batch loss 0.007790, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.012720, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.023096, batch error rate 0.000000%
# At minibatch 43400, batch loss 0.012044, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.024604, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.017000% currently going to do 131 epochs
# At minibatch 43600, batch loss 0.020130, batch error rate 0.000000%
# At minibatch 43700, batch loss 0.007734, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.007158, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.005833, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.012670, batch error rate 0.000000%
# After epoch 88: valid_err_rate: 0.017200% currently going to do 131 epochs
# At minibatch 44100, batch loss 0.004531, batch error rate 0.000000%
# At minibatch 44200, batch loss 0.016675, batch error rate 0.000000%
# At minibatch 44300, batch loss 0.007247, batch error rate 0.000000%
# At minibatch 44400, batch loss 0.007460, batch error rate 0.000000%
# At minibatch 44500, batch loss 0.006924, batch error rate 0.000000%
# After epoch 89: valid_err_rate: 0.017600% currently going to do 131 epochs
# At minibatch 44600, batch loss 0.015839, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.016390, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.009061, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.012112, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.033261, batch error rate 2.000000%
# After epoch 90: valid_err_rate: 0.017800% currently going to do 131 epochs
# At minibatch 45100, batch loss 0.080583, batch error rate 1.000000%
# At minibatch 45200, batch loss 0.027490, batch error rate 1.000000%
# At minibatch 45300, batch loss 0.012679, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.021799, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.027801, batch error rate 1.000000%
# After epoch 91: valid_err_rate: 0.017200% currently going to do 131 epochs
# At minibatch 45600, batch loss 0.018304, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.013983, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.008977, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.007486, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.007773, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.017800% currently going to do 131 epochs
# At minibatch 46100, batch loss 0.015774, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.025711, batch error rate 1.000000%
# At minibatch 46300, batch loss 0.010472, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.015851, batch error rate 0.000000%
# At minibatch 46500, batch loss 0.006024, batch error rate 0.000000%
# After epoch 93: valid_err_rate: 0.017600% currently going to do 131 epochs
# At minibatch 46600, batch loss 0.023586, batch error rate 1.000000%
# At minibatch 46700, batch loss 0.018971, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.019199, batch error rate 1.000000%
# At minibatch 46900, batch loss 0.009942, batch error rate 0.000000%
# At minibatch 47000, batch loss 0.010372, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.017700% currently going to do 131 epochs
# At minibatch 47100, batch loss 0.013517, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.009645, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.009819, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.037430, batch error rate 1.000000%
# At minibatch 47500, batch loss 0.014291, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.017200% currently going to do 131 epochs
# At minibatch 47600, batch loss 0.011527, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.019237, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.018005, batch error rate 1.000000%
# At minibatch 47900, batch loss 0.007783, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.004921, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.017800% currently going to do 131 epochs
# At minibatch 48100, batch loss 0.026076, batch error rate 1.000000%
# At minibatch 48200, batch loss 0.011669, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.013475, batch error rate 0.000000%
# At minibatch 48400, batch loss 0.015662, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.011653, batch error rate 0.000000%
# After epoch 97: valid_err_rate: 0.017300% currently going to do 131 epochs
# At minibatch 48600, batch loss 0.006597, batch error rate 0.000000%
# At minibatch 48700, batch loss 0.005379, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.013900, batch error rate 0.000000%
# At minibatch 48900, batch loss 0.020349, batch error rate 1.000000%
# At minibatch 49000, batch loss 0.008379, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.017300% currently going to do 131 epochs
# At minibatch 49100, batch loss 0.012289, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.004512, batch error rate 0.000000%
# At minibatch 49300, batch loss 0.011580, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.011812, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.030477, batch error rate 1.000000%
# After epoch 99: valid_err_rate: 0.017800% currently going to do 131 epochs
# At minibatch 49600, batch loss 0.005000, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.016418, batch error rate 1.000000%
# At minibatch 49800, batch loss 0.042811, batch error rate 1.000000%
# At minibatch 49900, batch loss 0.011636, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.004048, batch error rate 0.000000%
# After epoch 100: valid_err_rate: 0.017600% currently going to do 131 epochs
# At minibatch 50100, batch loss 0.011574, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.007344, batch error rate 0.000000%
# At minibatch 50300, batch loss 0.017498, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.012761, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.012566, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.017800% currently going to do 131 epochs
# At minibatch 50600, batch loss 0.044687, batch error rate 1.000000%
# At minibatch 50700, batch loss 0.008958, batch error rate 0.000000%
# At minibatch 50800, batch loss 0.018521, batch error rate 0.000000%
# At minibatch 50900, batch loss 0.006055, batch error rate 0.000000%
# At minibatch 51000, batch loss 0.007875, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.017500% currently going to do 131 epochs
# At minibatch 51100, batch loss 0.006669, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.017874, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.019986, batch error rate 1.000000%
# At minibatch 51400, batch loss 0.013973, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.010649, batch error rate 0.000000%
# After epoch 103: valid_err_rate: 0.017600% currently going to do 131 epochs
# At minibatch 51600, batch loss 0.005334, batch error rate 0.000000%
# At minibatch 51700, batch loss 0.006395, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.009015, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.032502, batch error rate 1.000000%
# At minibatch 52000, batch loss 0.012701, batch error rate 0.000000%
# After epoch 104: valid_err_rate: 0.017100% currently going to do 131 epochs
# At minibatch 52100, batch loss 0.024634, batch error rate 1.000000%
# At minibatch 52200, batch loss 0.008297, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.038486, batch error rate 1.000000%
# At minibatch 52400, batch loss 0.016923, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.030569, batch error rate 1.000000%
# After epoch 105: valid_err_rate: 0.017500% currently going to do 131 epochs
# At minibatch 52600, batch loss 0.006252, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.015502, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.040439, batch error rate 1.000000%
# At minibatch 52900, batch loss 0.007429, batch error rate 0.000000%
# At minibatch 53000, batch loss 0.011948, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.017200% currently going to do 131 epochs
# At minibatch 53100, batch loss 0.012261, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.008039, batch error rate 0.000000%
# At minibatch 53300, batch loss 0.008533, batch error rate 0.000000%
# At minibatch 53400, batch loss 0.004642, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.014921, batch error rate 0.000000%
# After epoch 107: valid_err_rate: 0.017100% currently going to do 131 epochs
# At minibatch 53600, batch loss 0.011605, batch error rate 0.000000%
# At minibatch 53700, batch loss 0.023267, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.027525, batch error rate 1.000000%
# At minibatch 53900, batch loss 0.006560, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.021625, batch error rate 1.000000%
# After epoch 108: valid_err_rate: 0.017200% currently going to do 131 epochs
# At minibatch 54100, batch loss 0.015588, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.008383, batch error rate 0.000000%
# At minibatch 54300, batch loss 0.007781, batch error rate 0.000000%
# At minibatch 54400, batch loss 0.009925, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.011503, batch error rate 0.000000%
# After epoch 109: valid_err_rate: 0.017400% currently going to do 131 epochs
# At minibatch 54600, batch loss 0.011848, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.019118, batch error rate 1.000000%
# At minibatch 54800, batch loss 0.023650, batch error rate 1.000000%
# At minibatch 54900, batch loss 0.025563, batch error rate 1.000000%
# At minibatch 55000, batch loss 0.008890, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.017700% currently going to do 131 epochs
# At minibatch 55100, batch loss 0.008800, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.019281, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.011065, batch error rate 0.000000%
# At minibatch 55400, batch loss 0.009718, batch error rate 0.000000%
# At minibatch 55500, batch loss 0.022330, batch error rate 1.000000%
# After epoch 111: valid_err_rate: 0.017400% currently going to do 131 epochs
# At minibatch 55600, batch loss 0.017898, batch error rate 1.000000%
# At minibatch 55700, batch loss 0.027466, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.006185, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.015856, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.006647, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.017400% currently going to do 131 epochs
# At minibatch 56100, batch loss 0.010129, batch error rate 0.000000%
# At minibatch 56200, batch loss 0.011431, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.012408, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.007472, batch error rate 0.000000%
# At minibatch 56500, batch loss 0.020971, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.016900% currently going to do 170 epochs
# At minibatch 56600, batch loss 0.018301, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.015600, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.005718, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.015962, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.030440, batch error rate 0.000000%
# After epoch 114: valid_err_rate: 0.017100% currently going to do 170 epochs
# At minibatch 57100, batch loss 0.011905, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.012132, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.011032, batch error rate 0.000000%
# At minibatch 57400, batch loss 0.017379, batch error rate 0.000000%
# At minibatch 57500, batch loss 0.010962, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.017200% currently going to do 170 epochs
# At minibatch 57600, batch loss 0.014107, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.008929, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.006509, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.006088, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.007245, batch error rate 0.000000%
# After epoch 116: valid_err_rate: 0.017600% currently going to do 170 epochs
# ...
# After epoch 173: valid_err_rate: 0.016900% currently going to do 211 epochs
# At minibatch 86600, batch loss 0.016746, batch error rate 0.000000%
# At minibatch 86700, batch loss 0.005698, batch error rate 0.000000%
# At minibatch 86800, batch loss 0.005309, batch error rate 0.000000%
# At minibatch 86900, batch loss 0.020995, batch error rate 0.000000%
# At minibatch 87000, batch loss 0.012964, batch error rate 0.000000%
# After epoch 174: valid_err_rate: 0.016400% currently going to do 211 epochs
# At minibatch 87100, batch loss 0.010341, batch error rate 0.000000%
# At minibatch 87200, batch loss 0.033479, batch error rate 1.000000%
# At minibatch 87300, batch loss 0.009015, batch error rate 0.000000%
# At minibatch 87400, batch loss 0.005976, batch error rate 0.000000%
# At minibatch 87500, batch loss 0.015923, batch error rate 0.000000%
# After epoch 175: valid_err_rate: 0.016900% currently going to do 211 epochs
# At minibatch 87600, batch loss 0.009697, batch error rate 0.000000%
# At minibatch 87700, batch loss 0.009450, batch error rate 0.000000%
# At minibatch 87800, batch loss 0.004439, batch error rate 0.000000%
# At minibatch 87900, batch loss 0.010877, batch error rate 0.000000%
# At minibatch 88000, batch loss 0.008731, batch error rate 0.000000%
# After epoch 176: valid_err_rate: 0.017200% currently going to do 211 epochs
# At minibatch 88100, batch loss 0.023258, batch error rate 0.000000%
# At minibatch 88200, batch loss 0.015416, batch error rate 0.000000%
# At minibatch 88300, batch loss 0.012638, batch error rate 0.000000%
# At minibatch 88400, batch loss 0.009531, batch error rate 0.000000%
# At minibatch 88500, batch loss 0.016090, batch error rate 0.000000%
# After epoch 177: valid_err_rate: 0.016800% currently going to do 211 epochs
# At minibatch 88600, batch loss 0.006922, batch error rate 0.000000%
# At minibatch 88700, batch loss 0.013487, batch error rate 0.000000%
# At minibatch 88800, batch loss 0.006927, batch error rate 0.000000%
# At minibatch 88900, batch loss 0.006457, batch error rate 0.000000%
# At minibatch 89000, batch loss 0.014207, batch error rate 0.000000%
# After epoch 178: valid_err_rate: 0.016700% currently going to do 211 epochs
# At minibatch 89100, batch loss 0.007823, batch error rate 0.000000%
# At minibatch 89200, batch loss 0.015943, batch error rate 0.000000%
# At minibatch 89300, batch loss 0.011409, batch error rate 0.000000%
# At minibatch 89400, batch loss 0.007978, batch error rate 0.000000%
# At minibatch 89500, batch loss 0.044074, batch error rate 1.000000%
# After epoch 179: valid_err_rate: 0.016400% currently going to do 211 epochs
# At minibatch 89600, batch loss 0.015574, batch error rate 1.000000%
# At minibatch 89700, batch loss 0.013482, batch error rate 0.000000%
# At minibatch 89800, batch loss 0.005954, batch error rate 0.000000%
# At minibatch 89900, batch loss 0.014077, batch error rate 0.000000%
# At minibatch 90000, batch loss 0.008992, batch error rate 0.000000%
# After epoch 180: valid_err_rate: 0.017900% currently going to do 211 epochs
# At minibatch 90100, batch loss 0.006778, batch error rate 0.000000%
# At minibatch 90200, batch loss 0.007919, batch error rate 0.000000%
# At minibatch 90300, batch loss 0.004779, batch error rate 0.000000%
# At minibatch 90400, batch loss 0.009601, batch error rate 0.000000%
# At minibatch 90500, batch loss 0.011297, batch error rate 0.000000%
# After epoch 181: valid_err_rate: 0.017200% currently going to do 211 epochs
# At minibatch 90600, batch loss 0.007170, batch error rate 0.000000%
# At minibatch 90700, batch loss 0.015060, batch error rate 0.000000%
# At minibatch 90800, batch loss 0.009570, batch error rate 0.000000%
# At minibatch 90900, batch loss 0.023798, batch error rate 1.000000%
# At minibatch 91000, batch loss 0.014243, batch error rate 0.000000%
# After epoch 182: valid_err_rate: 0.016800% currently going to do 211 epochs
# At minibatch 91100, batch loss 0.019308, batch error rate 0.000000%
# At minibatch 91200, batch loss 0.011519, batch error rate 0.000000%
# At minibatch 91300, batch loss 0.008737, batch error rate 0.000000%
# At minibatch 91400, batch loss 0.010508, batch error rate 0.000000%
# At minibatch 91500, batch loss 0.028621, batch error rate 0.000000%
# After epoch 183: valid_err_rate: 0.017000% currently going to do 211 epochs
# At minibatch 91600, batch loss 0.008656, batch error rate 0.000000%
# At minibatch 91700, batch loss 0.005506, batch error rate 0.000000%
# At minibatch 91800, batch loss 0.013655, batch error rate 0.000000%
# At minibatch 91900, batch loss 0.012099, batch error rate 0.000000%
# At minibatch 92000, batch loss 0.013692, batch error rate 0.000000%
# After epoch 184: valid_err_rate: 0.016700% currently going to do 211 epochs
# At minibatch 92100, batch loss 0.009014, batch error rate 0.000000%
# At minibatch 92200, batch loss 0.005933, batch error rate 0.000000%
# At minibatch 92300, batch loss 0.021204, batch error rate 0.000000%
# At minibatch 92400, batch loss 0.019498, batch error rate 1.000000%
# At minibatch 92500, batch loss 0.018322, batch error rate 0.000000%
# After epoch 185: valid_err_rate: 0.016900% currently going to do 211 epochs
# At minibatch 92600, batch loss 0.010442, batch error rate 0.000000%
# At minibatch 92700, batch loss 0.004352, batch error rate 0.000000%
# At minibatch 92800, batch loss 0.013893, batch error rate 0.000000%
# At minibatch 92900, batch loss 0.012237, batch error rate 0.000000%
# At minibatch 93000, batch loss 0.012565, batch error rate 0.000000%
# After epoch 186: valid_err_rate: 0.017500% currently going to do 211 epochs
# At minibatch 93100, batch loss 0.006439, batch error rate 0.000000%
# At minibatch 93200, batch loss 0.019877, batch error rate 0.000000%
# At minibatch 93300, batch loss 0.009879, batch error rate 0.000000%
# At minibatch 93400, batch loss 0.014605, batch error rate 0.000000%
# At minibatch 93500, batch loss 0.012640, batch error rate 0.000000%
# After epoch 187: valid_err_rate: 0.017100% currently going to do 211 epochs
# At minibatch 93600, batch loss 0.012775, batch error rate 0.000000%
# At minibatch 93700, batch loss 0.004304, batch error rate 0.000000%
# At minibatch 93800, batch loss 0.004995, batch error rate 0.000000%
# At minibatch 93900, batch loss 0.015120, batch error rate 0.000000%
# At minibatch 94000, batch loss 0.005385, batch error rate 0.000000%
# After epoch 188: valid_err_rate: 0.017300% currently going to do 211 epochs
# At minibatch 94100, batch loss 0.006628, batch error rate 0.000000%
# At minibatch 94200, batch loss 0.013387, batch error rate 0.000000%
# At minibatch 94300, batch loss 0.010216, batch error rate 0.000000%
# At minibatch 94400, batch loss 0.007812, batch error rate 0.000000%
# At minibatch 94500, batch loss 0.019266, batch error rate 1.000000%
# After epoch 189: valid_err_rate: 0.017100% currently going to do 211 epochs
# At minibatch 94600, batch loss 0.026264, batch error rate 1.000000%
# At minibatch 94700, batch loss 0.017703, batch error rate 0.000000%
# At minibatch 94800, batch loss 0.007091, batch error rate 0.000000%
# At minibatch 94900, batch loss 0.016012, batch error rate 0.000000%
# At minibatch 95000, batch loss 0.003846, batch error rate 0.000000%
# After epoch 190: valid_err_rate: 0.017000% currently going to do 211 epochs
# At minibatch 95100, batch loss 0.005837, batch error rate 0.000000%
# At minibatch 95200, batch loss 0.010787, batch error rate 0.000000%
# At minibatch 95300, batch loss 0.007389, batch error rate 0.000000%
# At minibatch 95400, batch loss 0.011190, batch error rate 0.000000%
# At minibatch 95500, batch loss 0.003744, batch error rate 0.000000%
# After epoch 191: valid_err_rate: 0.018100% currently going to do 211 epochs
# At minibatch 95600, batch loss 0.014701, batch error rate 0.000000%
# At minibatch 95700, batch loss 0.003918, batch error rate 0.000000%
# At minibatch 95800, batch loss 0.005547, batch error rate 0.000000%
# At minibatch 95900, batch loss 0.011081, batch error rate 0.000000%
# At minibatch 96000, batch loss 0.006228, batch error rate 0.000000%
# After epoch 192: valid_err_rate: 0.017300% currently going to do 211 epochs
# At minibatch 96100, batch loss 0.010604, batch error rate 0.000000%
# At minibatch 96200, batch loss 0.006034, batch error rate 0.000000%
# At minibatch 96300, batch loss 0.008475, batch error rate 0.000000%
# At minibatch 96400, batch loss 0.005060, batch error rate 0.000000%
# At minibatch 96500, batch loss 0.009718, batch error rate 0.000000%
# After epoch 193: valid_err_rate: 0.017000% currently going to do 211 epochs
# At minibatch 96600, batch loss 0.013050, batch error rate 0.000000%
# At minibatch 96700, batch loss 0.011008, batch error rate 0.000000%
# At minibatch 96800, batch loss 0.038579, batch error rate 1.000000%
# At minibatch 96900, batch loss 0.011434, batch error rate 0.000000%
# At minibatch 97000, batch loss 0.042961, batch error rate 1.000000%
# After epoch 194: valid_err_rate: 0.017400% currently going to do 211 epochs
# At minibatch 97100, batch loss 0.014998, batch error rate 0.000000%
# At minibatch 97200, batch loss 0.008241, batch error rate 0.000000%
# At minibatch 97300, batch loss 0.017702, batch error rate 0.000000%
# At minibatch 97400, batch loss 0.005185, batch error rate 0.000000%
# At minibatch 97500, batch loss 0.011941, batch error rate 0.000000%
# After epoch 195: valid_err_rate: 0.017000% currently going to do 211 epochs
# At minibatch 97600, batch loss 0.009744, batch error rate 0.000000%
# At minibatch 97700, batch loss 0.008106, batch error rate 0.000000%
# At minibatch 97800, batch loss 0.009176, batch error rate 0.000000%
# At minibatch 97900, batch loss 0.008078, batch error rate 0.000000%
# At minibatch 98000, batch loss 0.004380, batch error rate 0.000000%
# After epoch 196: valid_err_rate: 0.017100% currently going to do 211 epochs
# At minibatch 98100, batch loss 0.008604, batch error rate 0.000000%
# At minibatch 98200, batch loss 0.007566, batch error rate 0.000000%
# At minibatch 98300, batch loss 0.011749, batch error rate 0.000000%
# At minibatch 98400, batch loss 0.014349, batch error rate 0.000000%
# At minibatch 98500, batch loss 0.013397, batch error rate 0.000000%
# After epoch 197: valid_err_rate: 0.017600% currently going to do 211 epochs
# At minibatch 98600, batch loss 0.006871, batch error rate 0.000000%
# At minibatch 98700, batch loss 0.016016, batch error rate 0.000000%
# At minibatch 98800, batch loss 0.004172, batch error rate 0.000000%
# At minibatch 98900, batch loss 0.011424, batch error rate 0.000000%
# At minibatch 99000, batch loss 0.020558, batch error rate 0.000000%
# After epoch 198: valid_err_rate: 0.017100% currently going to do 211 epochs
# At minibatch 99100, batch loss 0.009435, batch error rate 0.000000%
# At minibatch 99200, batch loss 0.012676, batch error rate 0.000000%
# At minibatch 99300, batch loss 0.008395, batch error rate 0.000000%
# At minibatch 99400, batch loss 0.011299, batch error rate 0.000000%
# At minibatch 99500, batch loss 0.011616, batch error rate 0.000000%
# After epoch 199: valid_err_rate: 0.017300% currently going to do 211 epochs
# At minibatch 99600, batch loss 0.007748, batch error rate 0.000000%
# At minibatch 99700, batch loss 0.019454, batch error rate 0.000000%
# At minibatch 99800, batch loss 0.010155, batch error rate 0.000000%
# At minibatch 99900, batch loss 0.008065, batch error rate 0.000000%
# At minibatch 100000, batch loss 0.005503, batch error rate 0.000000%
# After epoch 200: valid_err_rate: 0.017500% currently going to do 211 epochs
# At minibatch 100100, batch loss 0.012665, batch error rate 0.000000%
# At minibatch 100200, batch loss 0.010685, batch error rate 0.000000%
# At minibatch 100300, batch loss 0.006862, batch error rate 0.000000%
# At minibatch 100400, batch loss 0.004306, batch error rate 0.000000%
# At minibatch 100500, batch loss 0.010466, batch error rate 0.000000%
# After epoch 201: valid_err_rate: 0.017500% currently going to do 211 epochs
# At minibatch 100600, batch loss 0.016220, batch error rate 0.000000%
# At minibatch 100700, batch loss 0.008136, batch error rate 0.000000%
# At minibatch 100800, batch loss 0.008141, batch error rate 0.000000%
# At minibatch 100900, batch loss 0.011808, batch error rate 0.000000%
# At minibatch 101000, batch loss 0.010938, batch error rate 0.000000%
# After epoch 202: valid_err_rate: 0.017400% currently going to do 211 epochs
# At minibatch 101100, batch loss 0.014994, batch error rate 0.000000%
# At minibatch 101200, batch loss 0.009470, batch error rate 0.000000%
# At minibatch 101300, batch loss 0.010746, batch error rate 0.000000%
# At minibatch 101400, batch loss 0.008355, batch error rate 0.000000%
# At minibatch 101500, batch loss 0.009816, batch error rate 0.000000%
# After epoch 203: valid_err_rate: 0.017700% currently going to do 211 epochs
# At minibatch 101600, batch loss 0.007129, batch error rate 0.000000%
# At minibatch 101700, batch loss 0.016517, batch error rate 0.000000%
# At minibatch 101800, batch loss 0.009731, batch error rate 0.000000%
# At minibatch 101900, batch loss 0.016874, batch error rate 0.000000%
# At minibatch 102000, batch loss 0.011245, batch error rate 0.000000%
# After epoch 204: valid_err_rate: 0.016600% currently going to do 211 epochs
# At minibatch 102100, batch loss 0.023846, batch error rate 1.000000%
# At minibatch 102200, batch loss 0.013232, batch error rate 0.000000%
# At minibatch 102300, batch loss 0.014339, batch error rate 0.000000%
# At minibatch 102400, batch loss 0.007152, batch error rate 0.000000%
# At minibatch 102500, batch loss 0.011706, batch error rate 0.000000%
# After epoch 205: valid_err_rate: 0.017200% currently going to do 211 epochs
# At minibatch 102600, batch loss 0.014040, batch error rate 0.000000%
# At minibatch 102700, batch loss 0.021415, batch error rate 0.000000%
# At minibatch 102800, batch loss 0.012781, batch error rate 0.000000%
# At minibatch 102900, batch loss 0.011095, batch error rate 0.000000%
# At minibatch 103000, batch loss 0.013467, batch error rate 0.000000%
# After epoch 206: valid_err_rate: 0.016700% currently going to do 211 epochs
# At minibatch 103100, batch loss 0.003480, batch error rate 0.000000%
# At minibatch 103200, batch loss 0.009003, batch error rate 0.000000%
# At minibatch 103300, batch loss 0.011879, batch error rate 0.000000%
# At minibatch 103400, batch loss 0.005322, batch error rate 0.000000%
# At minibatch 103500, batch loss 0.009071, batch error rate 0.000000%
# After epoch 207: valid_err_rate: 0.016700% currently going to do 211 epochs
# At minibatch 103600, batch loss 0.006801, batch error rate 0.000000%
# At minibatch 103700, batch loss 0.008710, batch error rate 0.000000%
# At minibatch 103800, batch loss 0.006754, batch error rate 0.000000%
# At minibatch 103900, batch loss 0.005501, batch error rate 0.000000%
# At minibatch 104000, batch loss 0.009337, batch error rate 0.000000%
# After epoch 208: valid_err_rate: 0.016900% currently going to do 211 epochs
# At minibatch 104100, batch loss 0.002470, batch error rate 0.000000%
# At minibatch 104200, batch loss 0.013965, batch error rate 0.000000%
# At minibatch 104300, batch loss 0.008460, batch error rate 0.000000%
# At minibatch 104400, batch loss 0.010026, batch error rate 0.000000%
# At minibatch 104500, batch loss 0.009210, batch error rate 0.000000%
# After epoch 209: valid_err_rate: 0.017300% currently going to do 211 epochs
# At minibatch 104600, batch loss 0.009343, batch error rate 0.000000%
# At minibatch 104700, batch loss 0.016051, batch error rate 0.000000%
# At minibatch 104800, batch loss 0.006479, batch error rate 0.000000%
# At minibatch 104900, batch loss 0.029737, batch error rate 1.000000%
# At minibatch 105000, batch loss 0.011247, batch error rate 0.000000%
# After epoch 210: valid_err_rate: 0.017500% currently going to do 211 epochs
# At minibatch 105100, batch loss 0.017353, batch error rate 0.000000%
# At minibatch 105200, batch loss 0.010281, batch error rate 0.000000%
# At minibatch 105300, batch loss 0.011304, batch error rate 0.000000%
# At minibatch 105400, batch loss 0.007659, batch error rate 0.000000%
# At minibatch 105500, batch loss 0.007061, batch error rate 0.000000%
# After epoch 211: valid_err_rate: 0.017300% currently going to do 211 epochs
# Test error rate: 0.018600

# %%
net = FeedForwardNet([
        AffineLayer(784,600),
        ReLULayer(),
        AffineLayer(600,400),
        ReLULayer(),
        AffineLayer(400,10),
        SoftMaxLayer()
        ])


SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream,
   alp=(4e-2, 5e-3),
   gamma = 0.05,
   delta = 1e-1,
   lambd = 1e-3,
   epsilon = 1e-10)

print("Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), ))
# Out:
# At minibatch 100, batch loss 0.711665, batch error rate 20.000000%
# At minibatch 200, batch loss 0.480603, batch error rate 12.000000%
# At minibatch 300, batch loss 0.486704, batch error rate 10.000000%
# At minibatch 400, batch loss 0.260863, batch error rate 5.000000%
# At minibatch 500, batch loss 0.406389, batch error rate 9.000000%
# After epoch 1: valid_err_rate: 0.097200% currently going to do 3 epochs
# At minibatch 600, batch loss 0.314624, batch error rate 11.000000%
# At minibatch 700, batch loss 0.265294, batch error rate 9.000000%
# At minibatch 800, batch loss 0.243822, batch error rate 7.000000%
# At minibatch 900, batch loss 0.293504, batch error rate 10.000000%
# At minibatch 1000, batch loss 0.370462, batch error rate 11.000000%
# After epoch 2: valid_err_rate: 0.070700% currently going to do 4 epochs
# At minibatch 1100, batch loss 0.202065, batch error rate 5.000000%
# At minibatch 1200, batch loss 0.309475, batch error rate 10.000000%
# At minibatch 1300, batch loss 0.201964, batch error rate 4.000000%
# At minibatch 1400, batch loss 0.223960, batch error rate 5.000000%
# At minibatch 1500, batch loss 0.188843, batch error rate 5.000000%
# After epoch 3: valid_err_rate: 0.058300% currently going to do 5 epochs
# At minibatch 1600, batch loss 0.143550, batch error rate 4.000000%
# At minibatch 1700, batch loss 0.256182, batch error rate 8.000000%
# At minibatch 1800, batch loss 0.333318, batch error rate 10.000000%
# At minibatch 1900, batch loss 0.122277, batch error rate 3.000000%
# At minibatch 2000, batch loss 0.434854, batch error rate 9.000000%
# After epoch 4: valid_err_rate: 0.047400% currently going to do 7 epochs
# At minibatch 2100, batch loss 0.172550, batch error rate 5.000000%
# At minibatch 2200, batch loss 0.120372, batch error rate 4.000000%
# At minibatch 2300, batch loss 0.148031, batch error rate 4.000000%
# At minibatch 2400, batch loss 0.253700, batch error rate 9.000000%
# At minibatch 2500, batch loss 0.164795, batch error rate 3.000000%
# After epoch 5: valid_err_rate: 0.038900% currently going to do 8 epochs
# At minibatch 2600, batch loss 0.132841, batch error rate 4.000000%
# At minibatch 2700, batch loss 0.137245, batch error rate 4.000000%
# At minibatch 2800, batch loss 0.141955, batch error rate 5.000000%
# At minibatch 2900, batch loss 0.160446, batch error rate 5.000000%
# At minibatch 3000, batch loss 0.107480, batch error rate 4.000000%
# After epoch 6: valid_err_rate: 0.035700% currently going to do 10 epochs
# At minibatch 3100, batch loss 0.062677, batch error rate 2.000000%
# At minibatch 3200, batch loss 0.101823, batch error rate 2.000000%
# At minibatch 3300, batch loss 0.072387, batch error rate 1.000000%
# At minibatch 3400, batch loss 0.165513, batch error rate 5.000000%
# At minibatch 3500, batch loss 0.083102, batch error rate 2.000000%
# After epoch 7: valid_err_rate: 0.033100% currently going to do 11 epochs
# At minibatch 3600, batch loss 0.081838, batch error rate 2.000000%
# At minibatch 3700, batch loss 0.070683, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.080282, batch error rate 4.000000%
# At minibatch 3900, batch loss 0.103589, batch error rate 2.000000%
# At minibatch 4000, batch loss 0.133197, batch error rate 5.000000%
# After epoch 8: valid_err_rate: 0.034900% currently going to do 11 epochs
# At minibatch 4100, batch loss 0.168380, batch error rate 5.000000%
# At minibatch 4200, batch loss 0.139512, batch error rate 3.000000%
# At minibatch 4300, batch loss 0.085559, batch error rate 3.000000%
# At minibatch 4400, batch loss 0.118227, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.069395, batch error rate 2.000000%
# After epoch 9: valid_err_rate: 0.028900% currently going to do 14 epochs
# At minibatch 4600, batch loss 0.099914, batch error rate 3.000000%
# At minibatch 4700, batch loss 0.075946, batch error rate 1.000000%
# At minibatch 4800, batch loss 0.051750, batch error rate 1.000000%
# At minibatch 4900, batch loss 0.110808, batch error rate 3.000000%
# At minibatch 5000, batch loss 0.122176, batch error rate 4.000000%
# After epoch 10: valid_err_rate: 0.029500% currently going to do 14 epochs
# At minibatch 5100, batch loss 0.076398, batch error rate 4.000000%
# At minibatch 5200, batch loss 0.077565, batch error rate 3.000000%
# At minibatch 5300, batch loss 0.091181, batch error rate 2.000000%
# At minibatch 5400, batch loss 0.036966, batch error rate 1.000000%
# At minibatch 5500, batch loss 0.025438, batch error rate 0.000000%
# After epoch 11: valid_err_rate: 0.025200% currently going to do 17 epochs
# At minibatch 5600, batch loss 0.024590, batch error rate 0.000000%
# At minibatch 5700, batch loss 0.048664, batch error rate 1.000000%
# At minibatch 5800, batch loss 0.148292, batch error rate 4.000000%
# At minibatch 5900, batch loss 0.065780, batch error rate 3.000000%
# At minibatch 6000, batch loss 0.070195, batch error rate 2.000000%
# After epoch 12: valid_err_rate: 0.025800% currently going to do 17 epochs
# At minibatch 6100, batch loss 0.079404, batch error rate 3.000000%
# At minibatch 6200, batch loss 0.039813, batch error rate 0.000000%
# At minibatch 6300, batch loss 0.063065, batch error rate 3.000000%
# At minibatch 6400, batch loss 0.096395, batch error rate 5.000000%
# At minibatch 6500, batch loss 0.026471, batch error rate 0.000000%
# After epoch 13: valid_err_rate: 0.025500% currently going to do 17 epochs
# At minibatch 6600, batch loss 0.057564, batch error rate 2.000000%
# At minibatch 6700, batch loss 0.058711, batch error rate 1.000000%
# At minibatch 6800, batch loss 0.044186, batch error rate 2.000000%
# At minibatch 6900, batch loss 0.052800, batch error rate 2.000000%
# At minibatch 7000, batch loss 0.057540, batch error rate 1.000000%
# After epoch 14: valid_err_rate: 0.024800% currently going to do 22 epochs
# At minibatch 7100, batch loss 0.041015, batch error rate 1.000000%
# At minibatch 7200, batch loss 0.049479, batch error rate 1.000000%
# At minibatch 7300, batch loss 0.086859, batch error rate 3.000000%
# At minibatch 7400, batch loss 0.054720, batch error rate 1.000000%
# At minibatch 7500, batch loss 0.047056, batch error rate 1.000000%
# After epoch 15: valid_err_rate: 0.022900% currently going to do 23 epochs
# At minibatch 7600, batch loss 0.040550, batch error rate 1.000000%
# At minibatch 7700, batch loss 0.028449, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.047678, batch error rate 1.000000%
# At minibatch 7900, batch loss 0.017589, batch error rate 0.000000%
# At minibatch 8000, batch loss 0.078046, batch error rate 3.000000%
# After epoch 16: valid_err_rate: 0.022300% currently going to do 25 epochs
# At minibatch 8100, batch loss 0.069705, batch error rate 2.000000%
# At minibatch 8200, batch loss 0.044010, batch error rate 1.000000%
# At minibatch 8300, batch loss 0.065478, batch error rate 3.000000%
# At minibatch 8400, batch loss 0.036911, batch error rate 2.000000%
# At minibatch 8500, batch loss 0.133014, batch error rate 3.000000%
# After epoch 17: valid_err_rate: 0.025500% currently going to do 25 epochs
# At minibatch 8600, batch loss 0.054702, batch error rate 2.000000%
# At minibatch 8700, batch loss 0.074525, batch error rate 2.000000%
# At minibatch 8800, batch loss 0.045444, batch error rate 1.000000%
# At minibatch 8900, batch loss 0.015439, batch error rate 0.000000%
# At minibatch 9000, batch loss 0.100686, batch error rate 4.000000%
# After epoch 18: valid_err_rate: 0.025500% currently going to do 25 epochs
# At minibatch 9100, batch loss 0.081864, batch error rate 3.000000%
# At minibatch 9200, batch loss 0.050995, batch error rate 2.000000%
# At minibatch 9300, batch loss 0.040606, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.022321, batch error rate 0.000000%
# At minibatch 9500, batch loss 0.044626, batch error rate 2.000000%
# After epoch 19: valid_err_rate: 0.021000% currently going to do 29 epochs
# At minibatch 9600, batch loss 0.058486, batch error rate 2.000000%
# At minibatch 9700, batch loss 0.122203, batch error rate 2.000000%
# At minibatch 9800, batch loss 0.052064, batch error rate 1.000000%
# At minibatch 9900, batch loss 0.103978, batch error rate 2.000000%
# At minibatch 10000, batch loss 0.101025, batch error rate 4.000000%
# After epoch 20: valid_err_rate: 0.022000% currently going to do 29 epochs
# At minibatch 10100, batch loss 0.027347, batch error rate 0.000000%
# At minibatch 10200, batch loss 0.024304, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.027720, batch error rate 0.000000%
# At minibatch 10400, batch loss 0.026961, batch error rate 1.000000%
# At minibatch 10500, batch loss 0.049965, batch error rate 2.000000%
# After epoch 21: valid_err_rate: 0.019600% currently going to do 32 epochs
# At minibatch 10600, batch loss 0.063608, batch error rate 3.000000%
# At minibatch 10700, batch loss 0.030592, batch error rate 0.000000%
# At minibatch 10800, batch loss 0.024525, batch error rate 1.000000%
# At minibatch 10900, batch loss 0.052812, batch error rate 1.000000%
# At minibatch 11000, batch loss 0.051219, batch error rate 1.000000%
# After epoch 22: valid_err_rate: 0.019800% currently going to do 32 epochs
# At minibatch 11100, batch loss 0.037957, batch error rate 1.000000%
# At minibatch 11200, batch loss 0.098378, batch error rate 3.000000%
# At minibatch 11300, batch loss 0.042100, batch error rate 1.000000%
# At minibatch 11400, batch loss 0.062330, batch error rate 1.000000%
# At minibatch 11500, batch loss 0.017330, batch error rate 0.000000%
# After epoch 23: valid_err_rate: 0.019800% currently going to do 32 epochs
# At minibatch 11600, batch loss 0.040846, batch error rate 2.000000%
# At minibatch 11700, batch loss 0.046882, batch error rate 1.000000%
# At minibatch 11800, batch loss 0.022051, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.020428, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.057606, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.019900% currently going to do 32 epochs
# At minibatch 12100, batch loss 0.021212, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.053070, batch error rate 2.000000%
# At minibatch 12300, batch loss 0.110832, batch error rate 1.000000%
# At minibatch 12400, batch loss 0.060624, batch error rate 1.000000%
# At minibatch 12500, batch loss 0.059995, batch error rate 1.000000%
# After epoch 25: valid_err_rate: 0.019700% currently going to do 32 epochs
# At minibatch 12600, batch loss 0.032796, batch error rate 1.000000%
# At minibatch 12700, batch loss 0.021204, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.023965, batch error rate 0.000000%
# At minibatch 12900, batch loss 0.017958, batch error rate 0.000000%
# At minibatch 13000, batch loss 0.025002, batch error rate 0.000000%
# After epoch 26: valid_err_rate: 0.020000% currently going to do 32 epochs
# At minibatch 13100, batch loss 0.027116, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.029312, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.045882, batch error rate 2.000000%
# At minibatch 13400, batch loss 0.054935, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.040377, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.019300% currently going to do 41 epochs
# At minibatch 13600, batch loss 0.011853, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.061501, batch error rate 2.000000%
# At minibatch 13800, batch loss 0.027151, batch error rate 0.000000%
# At minibatch 13900, batch loss 0.039590, batch error rate 1.000000%
# At minibatch 14000, batch loss 0.026027, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.019500% currently going to do 41 epochs
# At minibatch 14100, batch loss 0.021376, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.067529, batch error rate 1.000000%
# At minibatch 14300, batch loss 0.018855, batch error rate 1.000000%
# At minibatch 14400, batch loss 0.016190, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.024265, batch error rate 0.000000%
# After epoch 29: valid_err_rate: 0.019300% currently going to do 41 epochs
# At minibatch 14600, batch loss 0.013565, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.050072, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.021654, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.018792, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.048550, batch error rate 1.000000%
# After epoch 30: valid_err_rate: 0.019500% currently going to do 41 epochs
# At minibatch 15100, batch loss 0.023044, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.051582, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.026415, batch error rate 1.000000%
# At minibatch 15400, batch loss 0.045292, batch error rate 2.000000%
# At minibatch 15500, batch loss 0.050244, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.019500% currently going to do 41 epochs
# At minibatch 15600, batch loss 0.025561, batch error rate 1.000000%
# At minibatch 15700, batch loss 0.017566, batch error rate 0.000000%
# At minibatch 15800, batch loss 0.026483, batch error rate 1.000000%
# At minibatch 15900, batch loss 0.024207, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.025362, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.019700% currently going to do 41 epochs
# At minibatch 16100, batch loss 0.018273, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.113708, batch error rate 2.000000%
# At minibatch 16300, batch loss 0.029365, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.035045, batch error rate 1.000000%
# At minibatch 16500, batch loss 0.079165, batch error rate 2.000000%
# After epoch 33: valid_err_rate: 0.018800% currently going to do 50 epochs
# At minibatch 16600, batch loss 0.060781, batch error rate 2.000000%
# At minibatch 16700, batch loss 0.017942, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.030915, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.013780, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.036776, batch error rate 1.000000%
# After epoch 34: valid_err_rate: 0.019100% currently going to do 50 epochs
# At minibatch 17100, batch loss 0.026281, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.024651, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.017898, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.026854, batch error rate 2.000000%
# At minibatch 17500, batch loss 0.040047, batch error rate 2.000000%
# After epoch 35: valid_err_rate: 0.019300% currently going to do 50 epochs
# At minibatch 17600, batch loss 0.058196, batch error rate 1.000000%
# At minibatch 17700, batch loss 0.056874, batch error rate 1.000000%
# At minibatch 17800, batch loss 0.057017, batch error rate 1.000000%
# At minibatch 17900, batch loss 0.014880, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.014714, batch error rate 0.000000%
# After epoch 36: valid_err_rate: 0.019600% currently going to do 50 epochs
# At minibatch 18100, batch loss 0.022281, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.021985, batch error rate 1.000000%
# At minibatch 18300, batch loss 0.029199, batch error rate 1.000000%
# At minibatch 18400, batch loss 0.023562, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.020099, batch error rate 0.000000%
# After epoch 37: valid_err_rate: 0.018800% currently going to do 50 epochs
# At minibatch 18600, batch loss 0.077550, batch error rate 2.000000%
# At minibatch 18700, batch loss 0.036358, batch error rate 1.000000%
# At minibatch 18800, batch loss 0.033782, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.021747, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.020794, batch error rate 1.000000%
# After epoch 38: valid_err_rate: 0.019100% currently going to do 50 epochs
# At minibatch 19100, batch loss 0.029278, batch error rate 1.000000%
# At minibatch 19200, batch loss 0.021373, batch error rate 0.000000%
# At minibatch 19300, batch loss 0.073557, batch error rate 1.000000%
# At minibatch 19400, batch loss 0.027402, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.017240, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.019400% currently going to do 50 epochs
# At minibatch 19600, batch loss 0.016622, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.054496, batch error rate 2.000000%
# At minibatch 19800, batch loss 0.050954, batch error rate 2.000000%
# At minibatch 19900, batch loss 0.040495, batch error rate 1.000000%
# At minibatch 20000, batch loss 0.052337, batch error rate 1.000000%
# After epoch 40: valid_err_rate: 0.019100% currently going to do 50 epochs
# At minibatch 20100, batch loss 0.044125, batch error rate 1.000000%
# At minibatch 20200, batch loss 0.014897, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.034386, batch error rate 1.000000%
# At minibatch 20400, batch loss 0.031976, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.011959, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.019300% currently going to do 50 epochs
# At minibatch 20600, batch loss 0.040462, batch error rate 1.000000%
# At minibatch 20700, batch loss 0.027144, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.051853, batch error rate 2.000000%
# At minibatch 20900, batch loss 0.035970, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.026982, batch error rate 1.000000%
# After epoch 42: valid_err_rate: 0.019100% currently going to do 50 epochs
# At minibatch 21100, batch loss 0.018261, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.047892, batch error rate 2.000000%
# At minibatch 21300, batch loss 0.050640, batch error rate 1.000000%
# At minibatch 21400, batch loss 0.025181, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.065009, batch error rate 2.000000%
# After epoch 43: valid_err_rate: 0.019100% currently going to do 50 epochs
# At minibatch 21600, batch loss 0.015281, batch error rate 0.000000%
# At minibatch 21700, batch loss 0.045737, batch error rate 2.000000%
# At minibatch 21800, batch loss 0.026431, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.055013, batch error rate 2.000000%
# At minibatch 22000, batch loss 0.032896, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.019200% currently going to do 50 epochs
# At minibatch 22100, batch loss 0.027475, batch error rate 1.000000%
# At minibatch 22200, batch loss 0.031053, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.031682, batch error rate 1.000000%
# At minibatch 22400, batch loss 0.039863, batch error rate 1.000000%
# At minibatch 22500, batch loss 0.043797, batch error rate 2.000000%
# After epoch 45: valid_err_rate: 0.019200% currently going to do 50 epochs
# At minibatch 22600, batch loss 0.011504, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.031353, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.068116, batch error rate 1.000000%
# At minibatch 22900, batch loss 0.037052, batch error rate 1.000000%
# At minibatch 23000, batch loss 0.019770, batch error rate 0.000000%
# After epoch 46: valid_err_rate: 0.019800% currently going to do 50 epochs
# At minibatch 23100, batch loss 0.008271, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.050576, batch error rate 1.000000%
# At minibatch 23300, batch loss 0.023109, batch error rate 1.000000%
# At minibatch 23400, batch loss 0.019933, batch error rate 0.000000%
# At minibatch 23500, batch loss 0.075592, batch error rate 3.000000%
# After epoch 47: valid_err_rate: 0.019100% currently going to do 50 epochs
# At minibatch 23600, batch loss 0.031326, batch error rate 1.000000%
# At minibatch 23700, batch loss 0.054445, batch error rate 1.000000%
# At minibatch 23800, batch loss 0.027455, batch error rate 1.000000%
# At minibatch 23900, batch loss 0.027080, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.083630, batch error rate 3.000000%
# After epoch 48: valid_err_rate: 0.019400% currently going to do 50 epochs
# At minibatch 24100, batch loss 0.019694, batch error rate 1.000000%
# At minibatch 24200, batch loss 0.037622, batch error rate 2.000000%
# At minibatch 24300, batch loss 0.022183, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.018870, batch error rate 1.000000%
# At minibatch 24500, batch loss 0.015622, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.018800% currently going to do 50 epochs
# At minibatch 24600, batch loss 0.061528, batch error rate 1.000000%
# At minibatch 24700, batch loss 0.031447, batch error rate 1.000000%
# At minibatch 24800, batch loss 0.044808, batch error rate 1.000000%
# At minibatch 24900, batch loss 0.024229, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.023902, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.018900% currently going to do 50 epochs
# At minibatch 25100, batch loss 0.012053, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.018500, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.017242, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.040367, batch error rate 2.000000%
# At minibatch 25500, batch loss 0.042628, batch error rate 1.000000%
# After epoch 51: valid_err_rate: 0.018700% currently going to do 77 epochs
# At minibatch 25600, batch loss 0.042141, batch error rate 1.000000%
# At minibatch 25700, batch loss 0.017666, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.035085, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.017075, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.043634, batch error rate 1.000000%
# After epoch 52: valid_err_rate: 0.018600% currently going to do 79 epochs
# At minibatch 26100, batch loss 0.009229, batch error rate 0.000000%
# At minibatch 26200, batch loss 0.021132, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.019228, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.046990, batch error rate 1.000000%
# At minibatch 26500, batch loss 0.048982, batch error rate 2.000000%
# After epoch 53: valid_err_rate: 0.019300% currently going to do 79 epochs
# At minibatch 26600, batch loss 0.033007, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.032188, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.023807, batch error rate 1.000000%
# At minibatch 26900, batch loss 0.066525, batch error rate 2.000000%
# At minibatch 27000, batch loss 0.022521, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.018900% currently going to do 79 epochs
# At minibatch 27100, batch loss 0.044575, batch error rate 1.000000%
# At minibatch 27200, batch loss 0.008948, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.038305, batch error rate 1.000000%
# At minibatch 27400, batch loss 0.019229, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.014521, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.018400% currently going to do 83 epochs
# At minibatch 27600, batch loss 0.025696, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.025997, batch error rate 1.000000%
# At minibatch 27800, batch loss 0.076649, batch error rate 2.000000%
# At minibatch 27900, batch loss 0.045106, batch error rate 1.000000%
# At minibatch 28000, batch loss 0.016238, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.018400% currently going to do 83 epochs
# At minibatch 28100, batch loss 0.017992, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.028708, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.014021, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.029873, batch error rate 1.000000%
# At minibatch 28500, batch loss 0.022356, batch error rate 0.000000%
# After epoch 57: valid_err_rate: 0.019100% currently going to do 83 epochs
# At minibatch 28600, batch loss 0.036684, batch error rate 1.000000%
# At minibatch 28700, batch loss 0.016436, batch error rate 0.000000%
# At minibatch 28800, batch loss 0.031377, batch error rate 1.000000%
# At minibatch 28900, batch loss 0.013921, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.013315, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.019200% currently going to do 83 epochs
# At minibatch 29100, batch loss 0.019094, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.027535, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.042608, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.023859, batch error rate 0.000000%
# At minibatch 29500, batch loss 0.031392, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.018700% currently going to do 83 epochs
# At minibatch 29600, batch loss 0.037417, batch error rate 1.000000%
# At minibatch 29700, batch loss 0.035399, batch error rate 1.000000%
# At minibatch 29800, batch loss 0.018754, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.038332, batch error rate 1.000000%
# At minibatch 30000, batch loss 0.017831, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.019000% currently going to do 83 epochs
# At minibatch 30100, batch loss 0.014333, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.029834, batch error rate 1.000000%
# At minibatch 30300, batch loss 0.012812, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.022431, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.042762, batch error rate 1.000000%
# After epoch 61: valid_err_rate: 0.019100% currently going to do 83 epochs
# At minibatch 30600, batch loss 0.061114, batch error rate 1.000000%
# At minibatch 30700, batch loss 0.058195, batch error rate 1.000000%
# At minibatch 30800, batch loss 0.023684, batch error rate 1.000000%
# At minibatch 30900, batch loss 0.007229, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.062724, batch error rate 3.000000%
# After epoch 62: valid_err_rate: 0.019400% currently going to do 83 epochs
# At minibatch 31100, batch loss 0.016769, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.026278, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.021083, batch error rate 1.000000%
# At minibatch 31400, batch loss 0.015340, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.023374, batch error rate 0.000000%
# After epoch 63: valid_err_rate: 0.019100% currently going to do 83 epochs
# At minibatch 31600, batch loss 0.017809, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.021833, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.028453, batch error rate 1.000000%
# At minibatch 31900, batch loss 0.021815, batch error rate 1.000000%
# At minibatch 32000, batch loss 0.009226, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.019200% currently going to do 83 epochs
# At minibatch 32100, batch loss 0.026256, batch error rate 1.000000%
# At minibatch 32200, batch loss 0.021831, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.032697, batch error rate 1.000000%
# At minibatch 32400, batch loss 0.069882, batch error rate 2.000000%
# At minibatch 32500, batch loss 0.044016, batch error rate 1.000000%
# After epoch 65: valid_err_rate: 0.018500% currently going to do 83 epochs
# At minibatch 32600, batch loss 0.031252, batch error rate 1.000000%
# At minibatch 32700, batch loss 0.018367, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.015864, batch error rate 0.000000%
# At minibatch 32900, batch loss 0.026249, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.012182, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.018800% currently going to do 83 epochs
# At minibatch 33100, batch loss 0.062995, batch error rate 1.000000%
# At minibatch 33200, batch loss 0.031038, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.043867, batch error rate 2.000000%
# At minibatch 33400, batch loss 0.034862, batch error rate 1.000000%
# At minibatch 33500, batch loss 0.035860, batch error rate 1.000000%
# After epoch 67: valid_err_rate: 0.018700% currently going to do 83 epochs
# At minibatch 33600, batch loss 0.025195, batch error rate 1.000000%
# At minibatch 33700, batch loss 0.051806, batch error rate 2.000000%
# At minibatch 33800, batch loss 0.046258, batch error rate 2.000000%
# At minibatch 33900, batch loss 0.015751, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.013102, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.019700% currently going to do 83 epochs
# At minibatch 34100, batch loss 0.028299, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.027170, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.045119, batch error rate 1.000000%
# At minibatch 34400, batch loss 0.021169, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.014428, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.019000% currently going to do 83 epochs
# At minibatch 34600, batch loss 0.020642, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.035475, batch error rate 1.000000%
# At minibatch 34800, batch loss 0.042226, batch error rate 1.000000%
# At minibatch 34900, batch loss 0.018520, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.018367, batch error rate 0.000000%
# After epoch 70: valid_err_rate: 0.019200% currently going to do 83 epochs
# At minibatch 35100, batch loss 0.020484, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.012985, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.035713, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.035078, batch error rate 1.000000%
# At minibatch 35500, batch loss 0.035047, batch error rate 1.000000%
# After epoch 71: valid_err_rate: 0.019400% currently going to do 83 epochs
# At minibatch 35600, batch loss 0.039915, batch error rate 1.000000%
# At minibatch 35700, batch loss 0.037081, batch error rate 1.000000%
# At minibatch 35800, batch loss 0.084887, batch error rate 3.000000%
# At minibatch 35900, batch loss 0.026919, batch error rate 1.000000%
# At minibatch 36000, batch loss 0.028696, batch error rate 2.000000%
# After epoch 72: valid_err_rate: 0.018400% currently going to do 83 epochs
# At minibatch 36100, batch loss 0.025110, batch error rate 1.000000%
# At minibatch 36200, batch loss 0.010709, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.034055, batch error rate 2.000000%
# At minibatch 36400, batch loss 0.006409, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.016348, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.018100% currently going to do 110 epochs
# At minibatch 36600, batch loss 0.027938, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.044711, batch error rate 1.000000%
# At minibatch 36800, batch loss 0.021026, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.017502, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.031243, batch error rate 1.000000%
# After epoch 74: valid_err_rate: 0.018200% currently going to do 110 epochs
# At minibatch 37100, batch loss 0.027095, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.020951, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.015600, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.015201, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.012337, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.019000% currently going to do 110 epochs
# At minibatch 37600, batch loss 0.026469, batch error rate 1.000000%
# At minibatch 37700, batch loss 0.011193, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.028094, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.015973, batch error rate 0.000000%
# At minibatch 38000, batch loss 0.022532, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.018400% currently going to do 110 epochs
# At minibatch 38100, batch loss 0.057616, batch error rate 2.000000%
# At minibatch 38200, batch loss 0.054070, batch error rate 2.000000%
# At minibatch 38300, batch loss 0.035675, batch error rate 0.000000%
# At minibatch 38400, batch loss 0.025880, batch error rate 1.000000%
# At minibatch 38500, batch loss 0.042210, batch error rate 1.000000%
# After epoch 77: valid_err_rate: 0.018900% currently going to do 110 epochs
# At minibatch 38600, batch loss 0.025388, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.023630, batch error rate 1.000000%
# At minibatch 38800, batch loss 0.025988, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.015545, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.074811, batch error rate 1.000000%
# After epoch 78: valid_err_rate: 0.018800% currently going to do 110 epochs
# At minibatch 39100, batch loss 0.012511, batch error rate 0.000000%
# At minibatch 39200, batch loss 0.020340, batch error rate 0.000000%
# At minibatch 39300, batch loss 0.008312, batch error rate 0.000000%
# At minibatch 39400, batch loss 0.019979, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.026657, batch error rate 1.000000%
# After epoch 79: valid_err_rate: 0.018700% currently going to do 110 epochs
# At minibatch 39600, batch loss 0.014744, batch error rate 0.000000%
# At minibatch 39700, batch loss 0.016659, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.041880, batch error rate 1.000000%
# At minibatch 39900, batch loss 0.032376, batch error rate 1.000000%
# At minibatch 40000, batch loss 0.052065, batch error rate 3.000000%
# After epoch 80: valid_err_rate: 0.018200% currently going to do 110 epochs
# At minibatch 40100, batch loss 0.017518, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.016244, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.012902, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.031781, batch error rate 1.000000%
# At minibatch 40500, batch loss 0.018590, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 0.018900% currently going to do 110 epochs
# At minibatch 40600, batch loss 0.009104, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.074913, batch error rate 3.000000%
# At minibatch 40800, batch loss 0.026444, batch error rate 0.000000%
# At minibatch 40900, batch loss 0.036081, batch error rate 1.000000%
# At minibatch 41000, batch loss 0.010791, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.018200% currently going to do 110 epochs
# At minibatch 41100, batch loss 0.026957, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.020341, batch error rate 1.000000%
# At minibatch 41300, batch loss 0.021697, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.016073, batch error rate 0.000000%
# At minibatch 41500, batch loss 0.015831, batch error rate 0.000000%
# After epoch 83: valid_err_rate: 0.018500% currently going to do 110 epochs
# At minibatch 41600, batch loss 0.024349, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.013983, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.026577, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.013938, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.013130, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.019200% currently going to do 110 epochs
# At minibatch 42100, batch loss 0.034757, batch error rate 0.000000%
# At minibatch 42200, batch loss 0.012741, batch error rate 0.000000%
# At minibatch 42300, batch loss 0.044856, batch error rate 1.000000%
# At minibatch 42400, batch loss 0.012618, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.016718, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.018400% currently going to do 110 epochs
# At minibatch 42600, batch loss 0.014571, batch error rate 0.000000%
# At minibatch 42700, batch loss 0.015883, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.011471, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.050800, batch error rate 1.000000%
# At minibatch 43000, batch loss 0.022034, batch error rate 0.000000%
# After epoch 86: valid_err_rate: 0.018200% currently going to do 110 epochs
# At minibatch 43100, batch loss 0.056038, batch error rate 2.000000%
# At minibatch 43200, batch loss 0.039740, batch error rate 1.000000%
# At minibatch 43300, batch loss 0.007017, batch error rate 0.000000%
# At minibatch 43400, batch loss 0.014995, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.042545, batch error rate 1.000000%
# After epoch 87: valid_err_rate: 0.018600% currently going to do 110 epochs
# At minibatch 43600, batch loss 0.028761, batch error rate 1.000000%
# At minibatch 43700, batch loss 0.027841, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.012452, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.017093, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.015123, batch error rate 0.000000%
# After epoch 88: valid_err_rate: 0.018300% currently going to do 110 epochs
# At minibatch 44100, batch loss 0.012059, batch error rate 0.000000%
# At minibatch 44200, batch loss 0.040985, batch error rate 1.000000%
# At minibatch 44300, batch loss 0.047838, batch error rate 1.000000%
# At minibatch 44400, batch loss 0.007643, batch error rate 0.000000%
# At minibatch 44500, batch loss 0.015677, batch error rate 0.000000%
# After epoch 89: valid_err_rate: 0.018500% currently going to do 110 epochs
# At minibatch 44600, batch loss 0.013191, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.020712, batch error rate 0.000000%
# At minibatch 44800, batch loss 0.024141, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.022612, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.032832, batch error rate 0.000000%
# After epoch 90: valid_err_rate: 0.018800% currently going to do 110 epochs
# At minibatch 45100, batch loss 0.012776, batch error rate 0.000000%
# At minibatch 45200, batch loss 0.038179, batch error rate 1.000000%
# At minibatch 45300, batch loss 0.009705, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.026946, batch error rate 1.000000%
# At minibatch 45500, batch loss 0.064423, batch error rate 2.000000%
# After epoch 91: valid_err_rate: 0.019200% currently going to do 110 epochs
# At minibatch 45600, batch loss 0.006663, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.017960, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.007482, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.012505, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.025355, batch error rate 1.000000%
# After epoch 92: valid_err_rate: 0.017500% currently going to do 139 epochs
# At minibatch 46100, batch loss 0.024742, batch error rate 1.000000%
# At minibatch 46200, batch loss 0.021407, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.017187, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.032572, batch error rate 1.000000%
# At minibatch 46500, batch loss 0.045098, batch error rate 1.000000%
# After epoch 93: valid_err_rate: 0.019600% currently going to do 139 epochs
# At minibatch 46600, batch loss 0.020823, batch error rate 1.000000%
# At minibatch 46700, batch loss 0.025805, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.023940, batch error rate 1.000000%
# At minibatch 46900, batch loss 0.015811, batch error rate 0.000000%
# At minibatch 47000, batch loss 0.020517, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.018600% currently going to do 139 epochs
# At minibatch 47100, batch loss 0.012209, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.013119, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.013088, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.016394, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.023333, batch error rate 1.000000%
# After epoch 95: valid_err_rate: 0.018600% currently going to do 139 epochs
# At minibatch 47600, batch loss 0.017888, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.015290, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.032785, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.012651, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.013016, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.018000% currently going to do 139 epochs
# At minibatch 48100, batch loss 0.019961, batch error rate 0.000000%
# At minibatch 48200, batch loss 0.027961, batch error rate 1.000000%
# At minibatch 48300, batch loss 0.017934, batch error rate 0.000000%
# At minibatch 48400, batch loss 0.036458, batch error rate 1.000000%
# At minibatch 48500, batch loss 0.017472, batch error rate 1.000000%
# After epoch 97: valid_err_rate: 0.018900% currently going to do 139 epochs
# At minibatch 48600, batch loss 0.037391, batch error rate 1.000000%
# At minibatch 48700, batch loss 0.061438, batch error rate 1.000000%
# At minibatch 48800, batch loss 0.038930, batch error rate 1.000000%
# At minibatch 48900, batch loss 0.022012, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.016993, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.017900% currently going to do 139 epochs
# At minibatch 49100, batch loss 0.025870, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.020267, batch error rate 0.000000%
# At minibatch 49300, batch loss 0.015599, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.015958, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.058473, batch error rate 1.000000%
# After epoch 99: valid_err_rate: 0.018300% currently going to do 139 epochs
# At minibatch 49600, batch loss 0.017765, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.028031, batch error rate 0.000000%
# At minibatch 49800, batch loss 0.021313, batch error rate 1.000000%
# At minibatch 49900, batch loss 0.018111, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.078722, batch error rate 1.000000%
# After epoch 100: valid_err_rate: 0.018300% currently going to do 139 epochs
# At minibatch 50100, batch loss 0.017483, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.026730, batch error rate 1.000000%
# At minibatch 50300, batch loss 0.030503, batch error rate 1.000000%
# At minibatch 50400, batch loss 0.015976, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.009683, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.018000% currently going to do 139 epochs
# At minibatch 50600, batch loss 0.025565, batch error rate 1.000000%
# At minibatch 50700, batch loss 0.044564, batch error rate 2.000000%
# At minibatch 50800, batch loss 0.015717, batch error rate 0.000000%
# At minibatch 50900, batch loss 0.012144, batch error rate 0.000000%
# At minibatch 51000, batch loss 0.031883, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.018600% currently going to do 139 epochs
# At minibatch 51100, batch loss 0.029185, batch error rate 1.000000%
# At minibatch 51200, batch loss 0.007471, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.040030, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.014475, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.036633, batch error rate 0.000000%
# After epoch 103: valid_err_rate: 0.019000% currently going to do 139 epochs
# At minibatch 51600, batch loss 0.039815, batch error rate 1.000000%
# At minibatch 51700, batch loss 0.018078, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.018422, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.028110, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.041449, batch error rate 1.000000%
# After epoch 104: valid_err_rate: 0.018500% currently going to do 139 epochs
# At minibatch 52100, batch loss 0.035893, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.053599, batch error rate 1.000000%
# At minibatch 52300, batch loss 0.028542, batch error rate 1.000000%
# At minibatch 52400, batch loss 0.020403, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.026020, batch error rate 0.000000%
# After epoch 105: valid_err_rate: 0.018900% currently going to do 139 epochs
# At minibatch 52600, batch loss 0.017171, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.017474, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.019650, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.030184, batch error rate 1.000000%
# At minibatch 53000, batch loss 0.018234, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.018500% currently going to do 139 epochs
# At minibatch 53100, batch loss 0.028337, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.009255, batch error rate 0.000000%
# At minibatch 53300, batch loss 0.048157, batch error rate 1.000000%
# At minibatch 53400, batch loss 0.023250, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.011042, batch error rate 0.000000%
# After epoch 107: valid_err_rate: 0.018200% currently going to do 139 epochs
# At minibatch 53600, batch loss 0.061988, batch error rate 2.000000%
# At minibatch 53700, batch loss 0.017843, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.025983, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.012120, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.032112, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.018900% currently going to do 139 epochs
# At minibatch 54100, batch loss 0.019014, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.043200, batch error rate 1.000000%
# At minibatch 54300, batch loss 0.019972, batch error rate 0.000000%
# At minibatch 54400, batch loss 0.031711, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.007821, batch error rate 0.000000%
# After epoch 109: valid_err_rate: 0.018100% currently going to do 139 epochs
# At minibatch 54600, batch loss 0.013916, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.011241, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.027631, batch error rate 1.000000%
# At minibatch 54900, batch loss 0.013816, batch error rate 0.000000%
# At minibatch 55000, batch loss 0.021342, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.017300% currently going to do 166 epochs
# At minibatch 55100, batch loss 0.020168, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.013307, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.019641, batch error rate 0.000000%
# At minibatch 55400, batch loss 0.019528, batch error rate 0.000000%
# At minibatch 55500, batch loss 0.026435, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.018100% currently going to do 166 epochs
# At minibatch 55600, batch loss 0.022043, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.030830, batch error rate 1.000000%
# At minibatch 55800, batch loss 0.015418, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.058672, batch error rate 1.000000%
# At minibatch 56000, batch loss 0.013331, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.017700% currently going to do 166 epochs
# At minibatch 56100, batch loss 0.018748, batch error rate 0.000000%
# At minibatch 56200, batch loss 0.026955, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.025441, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.060308, batch error rate 2.000000%
# At minibatch 56500, batch loss 0.003622, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.018200% currently going to do 166 epochs
# At minibatch 56600, batch loss 0.024510, batch error rate 1.000000%
# At minibatch 56700, batch loss 0.027829, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.011334, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.027427, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.020527, batch error rate 0.000000%
# After epoch 114: valid_err_rate: 0.019100% currently going to do 166 epochs
# At minibatch 57100, batch loss 0.031564, batch error rate 1.000000%
# At minibatch 57200, batch loss 0.017939, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.031972, batch error rate 1.000000%
# At minibatch 57400, batch loss 0.076767, batch error rate 2.000000%
# At minibatch 57500, batch loss 0.013388, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.018300% currently going to do 166 epochs
# At minibatch 57600, batch loss 0.027176, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.021634, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.013293, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.074746, batch error rate 1.000000%
# At minibatch 58000, batch loss 0.023067, batch error rate 0.000000%
# After epoch 116: valid_err_rate: 0.018100% currently going to do 166 epochs
# ...
# At minibatch 136000, batch loss 0.010196, batch error rate 0.000000%
# After epoch 272: valid_err_rate: 0.017300% currently going to do 332 epochs
# At minibatch 136100, batch loss 0.008726, batch error rate 0.000000%
# At minibatch 136200, batch loss 0.017417, batch error rate 0.000000%
# At minibatch 136300, batch loss 0.010734, batch error rate 0.000000%
# At minibatch 136400, batch loss 0.015078, batch error rate 0.000000%
# At minibatch 136500, batch loss 0.013751, batch error rate 0.000000%
# After epoch 273: valid_err_rate: 0.017900% currently going to do 332 epochs
# At minibatch 136600, batch loss 0.025244, batch error rate 0.000000%
# At minibatch 136700, batch loss 0.020229, batch error rate 1.000000%
# At minibatch 136800, batch loss 0.015222, batch error rate 0.000000%
# At minibatch 136900, batch loss 0.027736, batch error rate 1.000000%
# At minibatch 137000, batch loss 0.019031, batch error rate 0.000000%
# After epoch 274: valid_err_rate: 0.017500% currently going to do 332 epochs
# At minibatch 137100, batch loss 0.014408, batch error rate 0.000000%
# At minibatch 137200, batch loss 0.020224, batch error rate 0.000000%
# At minibatch 137300, batch loss 0.016107, batch error rate 0.000000%
# At minibatch 137400, batch loss 0.012035, batch error rate 0.000000%
# At minibatch 137500, batch loss 0.011276, batch error rate 0.000000%
# After epoch 275: valid_err_rate: 0.017200% currently going to do 332 epochs
# At minibatch 137600, batch loss 0.011868, batch error rate 0.000000%
# At minibatch 137700, batch loss 0.021386, batch error rate 0.000000%
# At minibatch 137800, batch loss 0.011143, batch error rate 0.000000%
# At minibatch 137900, batch loss 0.011676, batch error rate 0.000000%
# At minibatch 138000, batch loss 0.012041, batch error rate 0.000000%
# After epoch 276: valid_err_rate: 0.017800% currently going to do 332 epochs
# At minibatch 138100, batch loss 0.014111, batch error rate 0.000000%
# At minibatch 138200, batch loss 0.016870, batch error rate 0.000000%
# At minibatch 138300, batch loss 0.041363, batch error rate 1.000000%
# At minibatch 138400, batch loss 0.017862, batch error rate 0.000000%
# At minibatch 138500, batch loss 0.020337, batch error rate 0.000000%
# After epoch 277: valid_err_rate: 0.017600% currently going to do 332 epochs
# At minibatch 138600, batch loss 0.009747, batch error rate 0.000000%
# At minibatch 138700, batch loss 0.009132, batch error rate 0.000000%
# At minibatch 138800, batch loss 0.013072, batch error rate 0.000000%
# At minibatch 138900, batch loss 0.024284, batch error rate 0.000000%
# At minibatch 139000, batch loss 0.008322, batch error rate 0.000000%
# After epoch 278: valid_err_rate: 0.017800% currently going to do 332 epochs
# At minibatch 139100, batch loss 0.009350, batch error rate 0.000000%
# At minibatch 139200, batch loss 0.017172, batch error rate 0.000000%
# At minibatch 139300, batch loss 0.015958, batch error rate 0.000000%
# At minibatch 139400, batch loss 0.043066, batch error rate 1.000000%
# At minibatch 139500, batch loss 0.022659, batch error rate 0.000000%
# After epoch 279: valid_err_rate: 0.016900% currently going to do 332 epochs
# At minibatch 139600, batch loss 0.010152, batch error rate 0.000000%
# At minibatch 139700, batch loss 0.016195, batch error rate 0.000000%
# At minibatch 139800, batch loss 0.010856, batch error rate 0.000000%
# At minibatch 139900, batch loss 0.017759, batch error rate 0.000000%
# At minibatch 140000, batch loss 0.047165, batch error rate 1.000000%
# After epoch 280: valid_err_rate: 0.017000% currently going to do 332 epochs
# At minibatch 140100, batch loss 0.015170, batch error rate 0.000000%
# At minibatch 140200, batch loss 0.016288, batch error rate 0.000000%
# At minibatch 140300, batch loss 0.009756, batch error rate 0.000000%
# At minibatch 140400, batch loss 0.013789, batch error rate 0.000000%
# At minibatch 140500, batch loss 0.008819, batch error rate 0.000000%
# After epoch 281: valid_err_rate: 0.016800% currently going to do 332 epochs
# At minibatch 140600, batch loss 0.018047, batch error rate 0.000000%
# At minibatch 140700, batch loss 0.015605, batch error rate 0.000000%
# At minibatch 140800, batch loss 0.012746, batch error rate 0.000000%
# At minibatch 140900, batch loss 0.021311, batch error rate 0.000000%
# At minibatch 141000, batch loss 0.023936, batch error rate 1.000000%
# After epoch 282: valid_err_rate: 0.017000% currently going to do 332 epochs
# At minibatch 141100, batch loss 0.011441, batch error rate 0.000000%
# At minibatch 141200, batch loss 0.040000, batch error rate 1.000000%
# At minibatch 141300, batch loss 0.009938, batch error rate 0.000000%
# At minibatch 141400, batch loss 0.016633, batch error rate 0.000000%
# At minibatch 141500, batch loss 0.021727, batch error rate 0.000000%
# After epoch 283: valid_err_rate: 0.016900% currently going to do 332 epochs
# At minibatch 141600, batch loss 0.018786, batch error rate 0.000000%
# At minibatch 141700, batch loss 0.013425, batch error rate 0.000000%
# At minibatch 141800, batch loss 0.017177, batch error rate 0.000000%
# At minibatch 141900, batch loss 0.016455, batch error rate 0.000000%
# At minibatch 142000, batch loss 0.034451, batch error rate 2.000000%
# After epoch 284: valid_err_rate: 0.017400% currently going to do 332 epochs
# At minibatch 142100, batch loss 0.020913, batch error rate 0.000000%
# At minibatch 142200, batch loss 0.012693, batch error rate 0.000000%
# At minibatch 142300, batch loss 0.005591, batch error rate 0.000000%
# At minibatch 142400, batch loss 0.008787, batch error rate 0.000000%
# At minibatch 142500, batch loss 0.012413, batch error rate 0.000000%
# After epoch 285: valid_err_rate: 0.017600% currently going to do 332 epochs
# At minibatch 142600, batch loss 0.011791, batch error rate 0.000000%
# At minibatch 142700, batch loss 0.025048, batch error rate 0.000000%
# At minibatch 142800, batch loss 0.023251, batch error rate 0.000000%
# At minibatch 142900, batch loss 0.010967, batch error rate 0.000000%
# At minibatch 143000, batch loss 0.011388, batch error rate 0.000000%
# After epoch 286: valid_err_rate: 0.016600% currently going to do 332 epochs
# At minibatch 143100, batch loss 0.010810, batch error rate 0.000000%
# At minibatch 143200, batch loss 0.016591, batch error rate 0.000000%
# At minibatch 143300, batch loss 0.009789, batch error rate 0.000000%
# At minibatch 143400, batch loss 0.016997, batch error rate 0.000000%
# At minibatch 143500, batch loss 0.011608, batch error rate 0.000000%
# After epoch 287: valid_err_rate: 0.017700% currently going to do 332 epochs
# At minibatch 143600, batch loss 0.012170, batch error rate 0.000000%
# At minibatch 143700, batch loss 0.014809, batch error rate 0.000000%
# At minibatch 143800, batch loss 0.016079, batch error rate 0.000000%
# At minibatch 143900, batch loss 0.014339, batch error rate 0.000000%
# At minibatch 144000, batch loss 0.030453, batch error rate 0.000000%
# After epoch 288: valid_err_rate: 0.016400% currently going to do 332 epochs
# At minibatch 144100, batch loss 0.015793, batch error rate 0.000000%
# At minibatch 144200, batch loss 0.015949, batch error rate 0.000000%
# At minibatch 144300, batch loss 0.012555, batch error rate 0.000000%
# At minibatch 144400, batch loss 0.014698, batch error rate 0.000000%
# At minibatch 144500, batch loss 0.036020, batch error rate 1.000000%
# After epoch 289: valid_err_rate: 0.016600% currently going to do 332 epochs
# At minibatch 144600, batch loss 0.020328, batch error rate 0.000000%
# At minibatch 144700, batch loss 0.016738, batch error rate 0.000000%
# At minibatch 144800, batch loss 0.035590, batch error rate 1.000000%
# At minibatch 144900, batch loss 0.018516, batch error rate 0.000000%
# At minibatch 145000, batch loss 0.014459, batch error rate 0.000000%
# After epoch 290: valid_err_rate: 0.017300% currently going to do 332 epochs
# At minibatch 145100, batch loss 0.016189, batch error rate 0.000000%
# At minibatch 145200, batch loss 0.023340, batch error rate 0.000000%
# At minibatch 145300, batch loss 0.013812, batch error rate 0.000000%
# At minibatch 145400, batch loss 0.029956, batch error rate 1.000000%
# At minibatch 145500, batch loss 0.026789, batch error rate 0.000000%
# After epoch 291: valid_err_rate: 0.017200% currently going to do 332 epochs
# At minibatch 145600, batch loss 0.007646, batch error rate 0.000000%
# At minibatch 145700, batch loss 0.014774, batch error rate 0.000000%
# At minibatch 145800, batch loss 0.020977, batch error rate 0.000000%
# At minibatch 145900, batch loss 0.013289, batch error rate 0.000000%
# At minibatch 146000, batch loss 0.013587, batch error rate 0.000000%
# After epoch 292: valid_err_rate: 0.017400% currently going to do 332 epochs
# At minibatch 146100, batch loss 0.021113, batch error rate 0.000000%
# At minibatch 146200, batch loss 0.017082, batch error rate 0.000000%
# At minibatch 146300, batch loss 0.008616, batch error rate 0.000000%
# At minibatch 146400, batch loss 0.006366, batch error rate 0.000000%
# At minibatch 146500, batch loss 0.019205, batch error rate 0.000000%
# After epoch 293: valid_err_rate: 0.017500% currently going to do 332 epochs
# At minibatch 146600, batch loss 0.010841, batch error rate 0.000000%
# At minibatch 146700, batch loss 0.015625, batch error rate 0.000000%
# At minibatch 146800, batch loss 0.011257, batch error rate 0.000000%
# At minibatch 146900, batch loss 0.013606, batch error rate 0.000000%
# At minibatch 147000, batch loss 0.009141, batch error rate 0.000000%
# After epoch 294: valid_err_rate: 0.017100% currently going to do 332 epochs
# At minibatch 147100, batch loss 0.016443, batch error rate 0.000000%
# At minibatch 147200, batch loss 0.012853, batch error rate 0.000000%
# At minibatch 147300, batch loss 0.007841, batch error rate 0.000000%
# At minibatch 147400, batch loss 0.023877, batch error rate 1.000000%
# At minibatch 147500, batch loss 0.013394, batch error rate 0.000000%
# After epoch 295: valid_err_rate: 0.016800% currently going to do 332 epochs
# At minibatch 147600, batch loss 0.021398, batch error rate 0.000000%
# At minibatch 147700, batch loss 0.009814, batch error rate 0.000000%
# At minibatch 147800, batch loss 0.012461, batch error rate 0.000000%
# At minibatch 147900, batch loss 0.020817, batch error rate 0.000000%
# At minibatch 148000, batch loss 0.019875, batch error rate 0.000000%
# After epoch 296: valid_err_rate: 0.017100% currently going to do 332 epochs
# At minibatch 148100, batch loss 0.012084, batch error rate 0.000000%
# At minibatch 148200, batch loss 0.021222, batch error rate 0.000000%
# At minibatch 148300, batch loss 0.008424, batch error rate 0.000000%
# At minibatch 148400, batch loss 0.009516, batch error rate 0.000000%
# At minibatch 148500, batch loss 0.022439, batch error rate 0.000000%
# After epoch 297: valid_err_rate: 0.017500% currently going to do 332 epochs
# At minibatch 148600, batch loss 0.009522, batch error rate 0.000000%
# At minibatch 148700, batch loss 0.016093, batch error rate 0.000000%
# At minibatch 148800, batch loss 0.016575, batch error rate 0.000000%
# At minibatch 148900, batch loss 0.019624, batch error rate 0.000000%
# At minibatch 149000, batch loss 0.015355, batch error rate 0.000000%
# After epoch 298: valid_err_rate: 0.016700% currently going to do 332 epochs
# At minibatch 149100, batch loss 0.018422, batch error rate 0.000000%
# At minibatch 149200, batch loss 0.014665, batch error rate 0.000000%
# At minibatch 149300, batch loss 0.016165, batch error rate 0.000000%
# At minibatch 149400, batch loss 0.019175, batch error rate 0.000000%
# At minibatch 149500, batch loss 0.017019, batch error rate 0.000000%
# After epoch 299: valid_err_rate: 0.017200% currently going to do 332 epochs
# At minibatch 149600, batch loss 0.027029, batch error rate 0.000000%
# At minibatch 149700, batch loss 0.025832, batch error rate 1.000000%
# At minibatch 149800, batch loss 0.014366, batch error rate 0.000000%
# At minibatch 149900, batch loss 0.009832, batch error rate 0.000000%
# At minibatch 150000, batch loss 0.008036, batch error rate 0.000000%
# After epoch 300: valid_err_rate: 0.016600% currently going to do 332 epochs
# At minibatch 150100, batch loss 0.014784, batch error rate 0.000000%
# At minibatch 150200, batch loss 0.015659, batch error rate 0.000000%
# At minibatch 150300, batch loss 0.012804, batch error rate 0.000000%
# At minibatch 150400, batch loss 0.027241, batch error rate 1.000000%
# At minibatch 150500, batch loss 0.016212, batch error rate 0.000000%
# After epoch 301: valid_err_rate: 0.016700% currently going to do 332 epochs
# At minibatch 150600, batch loss 0.015414, batch error rate 0.000000%
# At minibatch 150700, batch loss 0.008651, batch error rate 0.000000%
# At minibatch 150800, batch loss 0.042226, batch error rate 1.000000%
# At minibatch 150900, batch loss 0.025648, batch error rate 1.000000%
# At minibatch 151000, batch loss 0.011952, batch error rate 0.000000%
# After epoch 302: valid_err_rate: 0.017800% currently going to do 332 epochs
# At minibatch 151100, batch loss 0.007756, batch error rate 0.000000%
# At minibatch 151200, batch loss 0.012785, batch error rate 0.000000%
# At minibatch 151300, batch loss 0.015757, batch error rate 0.000000%
# At minibatch 151400, batch loss 0.008829, batch error rate 0.000000%
# At minibatch 151500, batch loss 0.015093, batch error rate 0.000000%
# After epoch 303: valid_err_rate: 0.016300% currently going to do 332 epochs
# At minibatch 151600, batch loss 0.023094, batch error rate 0.000000%
# At minibatch 151700, batch loss 0.021603, batch error rate 0.000000%
# At minibatch 151800, batch loss 0.024188, batch error rate 0.000000%
# At minibatch 151900, batch loss 0.008808, batch error rate 0.000000%
# At minibatch 152000, batch loss 0.023613, batch error rate 0.000000%
# After epoch 304: valid_err_rate: 0.016200% currently going to do 332 epochs
# At minibatch 152100, batch loss 0.033512, batch error rate 1.000000%
# At minibatch 152200, batch loss 0.007643, batch error rate 0.000000%
# At minibatch 152300, batch loss 0.033019, batch error rate 1.000000%
# At minibatch 152400, batch loss 0.011360, batch error rate 0.000000%
# At minibatch 152500, batch loss 0.024070, batch error rate 0.000000%
# After epoch 305: valid_err_rate: 0.017100% currently going to do 332 epochs
# At minibatch 152600, batch loss 0.008543, batch error rate 0.000000%
# At minibatch 152700, batch loss 0.011826, batch error rate 0.000000%
# At minibatch 152800, batch loss 0.014356, batch error rate 0.000000%
# At minibatch 152900, batch loss 0.028258, batch error rate 0.000000%
# At minibatch 153000, batch loss 0.010867, batch error rate 0.000000%
# After epoch 306: valid_err_rate: 0.016900% currently going to do 332 epochs
# At minibatch 153100, batch loss 0.021123, batch error rate 1.000000%
# At minibatch 153200, batch loss 0.008838, batch error rate 0.000000%
# At minibatch 153300, batch loss 0.005521, batch error rate 0.000000%
# At minibatch 153400, batch loss 0.009165, batch error rate 0.000000%
# At minibatch 153500, batch loss 0.014737, batch error rate 0.000000%
# After epoch 307: valid_err_rate: 0.017200% currently going to do 332 epochs
# At minibatch 153600, batch loss 0.013583, batch error rate 0.000000%
# At minibatch 153700, batch loss 0.020727, batch error rate 1.000000%
# At minibatch 153800, batch loss 0.010457, batch error rate 0.000000%
# At minibatch 153900, batch loss 0.017305, batch error rate 0.000000%
# At minibatch 154000, batch loss 0.012653, batch error rate 0.000000%
# After epoch 308: valid_err_rate: 0.016900% currently going to do 332 epochs
# At minibatch 154100, batch loss 0.013664, batch error rate 0.000000%
# At minibatch 154200, batch loss 0.015345, batch error rate 0.000000%
# At minibatch 154300, batch loss 0.021103, batch error rate 0.000000%
# At minibatch 154400, batch loss 0.014016, batch error rate 0.000000%
# At minibatch 154500, batch loss 0.016139, batch error rate 0.000000%
# After epoch 309: valid_err_rate: 0.017400% currently going to do 332 epochs
# At minibatch 154600, batch loss 0.045709, batch error rate 1.000000%
# At minibatch 154700, batch loss 0.016142, batch error rate 0.000000%
# Setting network parameters from after epoch 221
# Test error rate: 0.018700

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.018599999999999998

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
def id_vect(n, k):
    return [1 if i+1==k else 0 for i in range(n)]

def normalize_y(Y, n):
    return np.array([id_vect(n, y+1) for y in Y.ravel()])

# %%
print("The streams return batches containing %s" % (mnist_train_stream.sources,))

print("Each trainin batch consits of a tuple containing:")
for element in next(mnist_train_stream.get_epoch_iterator()):
    print(" - an array of size %s containing %s" % (element.shape, element.dtype))
    
print("Validation/test batches consits of tuples containing:")
for element in next(mnist_test_stream.get_epoch_iterator()):
    print(" - an array of size %s containing %s" % (element.shape, element.dtype))
# Out:
# The streams return batches containing ('features', 'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %%
img_size = 28
img_size_flat = img_size * img_size
img_shape = (img_size, img_size)
num_channels = 1
num_classes = 10

# %%
import tensorflow as tf

# %%
def get_weights(shape):
    return tf.Variable(tf.random_normal(shape, stddev=0.05))

def get_bias(length):
    return tf.Variable(tf.constant(0., shape=[length]))

def ConvLayer(prevLayer, num_prev, filter_size, num_filters, strides = [1,1,1,1]):
    shape = [filter_size, filter_size, num_prev, num_filters]
    weights = get_weights(shape)
    biases = get_bias(num_filters)
    
    layer = tf.nn.conv2d(input=prevLayer,
                         filter=weights,
                         strides=strides,
                         padding='SAME')
    layer += biases
    return layer

def PoolingLayer(prevLayer, k_size=[1, 2, 2, 1], strides=[1, 2, 2, 1]):
    return tf.nn.max_pool(value=prevLayer,
                           ksize=k_size,
                           strides=strides,
                           padding='SAME')
    
    
def ReLULayer(prevLayer):
    return tf.nn.relu(prevLayer)

def FullyConnLayer(prevLayer, num_in, num_out):
    weights = get_weights([num_in, num_out])
    biases = get_bias(num_out)
    return tf.matmul(prevLayer, weights) + biases

def SoftMaxLayer(prevLayer):
    return tf.nn.softmax(prevLayer)

# %%
def flatten_layer(layer):
    layer_shape = layer.get_shape()

    num_features = layer_shape[1:4].num_elements()
    
    layer_flat = tf.reshape(layer, [-1, num_features])

    return layer_flat, num_features

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x')
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])

y_true = tf.placeholder(tf.float32, shape=[None, 10], name='y_true')
y_true_cls = tf.argmax(y_true, dimension=1)

# %%
layer1 = ConvLayer(prevLayer=x_image,
                   num_prev=num_channels,
                   filter_size=3,
                   num_filters=32)
layer2 = ReLULayer(prevLayer=layer1)
layer3 = PoolingLayer(layer2)

layer4 = ConvLayer(prevLayer=layer3,
                   num_prev=32,
                   filter_size=5,
                   num_filters=16)
layer5 = ReLULayer(prevLayer=layer4)
layer6 = PoolingLayer(layer5)

layer_flat6, num_features6 = flatten_layer(layer6)
layer7 = FullyConnLayer(prevLayer=layer_flat6,
                       num_in=num_features6,
                       num_out=100)
layer8 = ReLULayer(layer7)
layer9 = FullyConnLayer(prevLayer=layer8,
                       num_in=100,
                       num_out=10)
y_pred = SoftMaxLayer(layer9)
y_pred_cls = tf.argmax(y_pred, dimension=1)

# %%
cross_ent = tf.nn.softmax_cross_entropy_with_logits(logits=layer9,labels=y_true)
loss = tf.reduce_mean(cross_ent)

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=5e-3).minimize(loss)

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
def train():
    try:
        i = 0
        while(True):
            x_batch, y_true_batch = next(mnist_train_stream.get_epoch_iterator())
            feed_dict_train = {x: x_batch.T,
                               y_true: normalize_y(y_true_batch, 10)}
            session.run(optimizer, feed_dict=feed_dict_train)
            if i % 100 == 0:
                L = session.run(loss, feed_dict=feed_dict_train)
                Acc = session.run(accuracy, feed_dict=feed_dict_train)
                if i % 100 == 0:
                    print("At iteration %d, batch loss %f, batch error  %f%%" % (i, L, 100. - Acc*100))
            i += 1
# Out:
#   File "<ipython-input-17-1e5bdce2ce46>", line 16
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
session = tf.Session()
session.run(tf.global_variables_initializer())

# %%
train()
# Out:
# At iteration 0, batch loss 2.228532, batch error  86.000000%
# At iteration 100, batch loss 0.166826, batch error  5.000001%
# At iteration 200, batch loss 0.030468, batch error  0.000000%
# At iteration 300, batch loss 0.170517, batch error  5.000001%
# At iteration 400, batch loss 0.057012, batch error  0.999999%
# At iteration 500, batch loss 0.016683, batch error  0.000000%
# At iteration 600, batch loss 0.016175, batch error  0.000000%
# At iteration 700, batch loss 0.028792, batch error  1.999998%
# At iteration 800, batch loss 0.014322, batch error  0.999999%
# At iteration 900, batch loss 0.023787, batch error  0.999999%
# At iteration 1000, batch loss 0.021379, batch error  0.999999%
# At iteration 1100, batch loss 0.014269, batch error  0.000000%
# At iteration 1200, batch loss 0.016991, batch error  0.999999%
# At iteration 1300, batch loss 0.134370, batch error  2.999997%
# At iteration 1400, batch loss 0.057000, batch error  0.999999%
# At iteration 1500, batch loss 0.009480, batch error  0.000000%
# At iteration 1600, batch loss 0.014688, batch error  0.000000%
# At iteration 1700, batch loss 0.007589, batch error  0.000000%
# At iteration 1800, batch loss 0.005826, batch error  0.000000%
# At iteration 1900, batch loss 0.008965, batch error  0.999999%
# At iteration 2000, batch loss 0.007068, batch error  0.000000%
# At iteration 2100, batch loss 0.011645, batch error  0.000000%
# At iteration 2200, batch loss 0.006752, batch error  0.000000%
# At iteration 2300, batch loss 0.013249, batch error  0.000000%
# At iteration 2400, batch loss 0.003325, batch error  0.000000%
# At iteration 2500, batch loss 0.004085, batch error  0.000000%
# At iteration 2600, batch loss 0.141971, batch error  0.999999%
# At iteration 2700, batch loss 0.008430, batch error  0.000000%
# At iteration 2800, batch loss 0.009893, batch error  0.000000%
# At iteration 2900, batch loss 0.010321, batch error  0.999999%
# At iteration 3000, batch loss 0.009100, batch error  0.000000%
# At iteration 3100, batch loss 0.077360, batch error  2.999997%
# At iteration 3200, batch loss 0.004171, batch error  0.000000%
# At iteration 3300, batch loss 0.003731, batch error  0.000000%
# At iteration 3400, batch loss 0.007927, batch error  0.999999%
# At iteration 3500, batch loss 0.016230, batch error  0.999999%
# At iteration 3600, batch loss 0.013705, batch error  0.999999%
# At iteration 3700, batch loss 0.006557, batch error  0.000000%
# At iteration 3800, batch loss 0.001838, batch error  0.000000%
# At iteration 3900, batch loss 0.001247, batch error  0.000000%
# At iteration 4000, batch loss 0.003946, batch error  0.000000%
# At iteration 4100, batch loss 0.007315, batch error  0.000000%
# At iteration 4200, batch loss 0.025348, batch error  0.999999%
# At iteration 4300, batch loss 0.003705, batch error  0.000000%
# At iteration 4400, batch loss 0.000178, batch error  0.000000%
# At iteration 4500, batch loss 0.000413, batch error  0.000000%
# At iteration 4600, batch loss 0.002830, batch error  0.000000%
# At iteration 4700, batch loss 0.002516, batch error  0.000000%
# At iteration 4800, batch loss 0.000582, batch error  0.000000%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-93fd337a0d5c> in <module>()
# ----> 1 train()
#
# <ipython-input-46-ed3b8e4e1b20> in train()
#      18         # TensorFlow assigns the variables in feed_dict_train
#      19         # to the placeholder variables and then runs the optimizer.
# ---> 20         session.run(optimizer, feed_dict=feed_dict_train)
#      21
#      22         # Print status every 100 iterations.
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
totalAcc = 0.
i = 0
for X, Y in mnist_test_stream.get_epoch_iterator():
    feed_dict = {x: X.T, y_true: normalize_y(Y, 10)}
    totalAcc += session.run(accuracy, feed_dict=feed_dict)
    i += 1
print('Error: ',100*(1. - totalAcc/i))
# Out:
# Error:  1.21000006795

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.
